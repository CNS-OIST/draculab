# %% [markdown]
# ## kWTA_ei_mp
# This program explores the implementation of a kWTA network using multiple simulations of E-I networks.
#
# The code here is based on the code from kWTA_ei.ipynb .
#
# Sergio Verduzco,
# November 2017

# %% [markdown]
# ## Regarding multiprocessing/multithreading as done below.
#
# When importing Pool from the `multiprocessing` module, `pool.map` will provide a multiprocess version of the `map` function.
# When importing Pool from the `multiprocessing.dummy` module, `pool.map` will provide a multithread version of the `map` function.
# See: http://chriskiehl.com/article/parallelism-in-one-line/
#
# Both multithreading and multiprocessing can't currently work this way.
#
# As draculab currently is, you can't multithread because `scipy.integrate.odeint` uses the Isoda solver, which can't have two instances running at the same time. See: https://docs.scipy.org/doc/scipy-0.17.1/reference/generated/scipy.integrate.ode.html#scipy.integrate.odeint .
#
# A possible solution is to replace odeint with `scipy.integrate.ode`, using the set_integrator method to set "dopri5" as the solver. This seems error prone, and probably isn't worth it considering the GIL issue with Python threads.
#
# The problem with multiprocessing, as implemented with `multiprocessing.pool.map`, is that the draculab network instances need to be pickled, and yet, they are not picklable. The solution is to give Python a way to pickle the ei_net objects: https://stackoverflow.com/questions/1816958/cant-pickle-type-instancemethod-when-using-multiprocessing-pool-map . To achieve this, the simplest solution may be to use `dill`.
#
# Since there is a `copyreg` module to give pickle the right functions to serialize/deserialize a particular type of object, it seemed like I could get away with:
#
#     import dill
#     import copyreg
#     # The next lines specify the methods to pickle and unpickle draculab networks
#     copyreg.constructor(dill.loads) # declares dill.loads to be a valid constructor
#     copyreg.pickle(network, dill.dumps, dill.loads)
# Unfortunately, this causes the pickling process to go into untold (infinite?) depths of recursion, higher than 10000.
#
# Fortunately, the makers of dill also have their own multiprocessing module, which works with dill:
#
# https://stackoverflow.com/questions/19984152/what-can-multiprocessing-and-dill-do-together?rq=1
#
# https://github.com/uqfoundation/pathos
#
# This works well, but there is still one more caveat. My `ei_net.run` function stores its results in member arrays, as well as in the network's synaptic weights and state. When we call the `run` method with `ProcessingPool.map`, however, the `ei_net` object is not modified. `map` actually pickles the object, and ships it to a process where it is unpacked and worked on. This unpacked object is a clone of the original `ei_net` object, and it is discarded once its `run` method is finished (https://stackoverflow.com/questions/15857838/modify-object-in-python-multiprocessing#15858559). Thus, all the results are in objects that get discarded.
#
# The solution I have is to make the `ei_net.run` method return its `ei_net` instance, so `pool.map` will return a list with the `ei_net` instances that were actually executed.
# This is why the original `ei_nets` list used below replaced by the results of `pool.map`. Otherwise it would be left populated by instances that have never been run.

# %%
from draculab import *
from matplotlib import pyplot as plt
import time
from matplotlib.animation import FuncAnimation
import dill
from pathos.multiprocessing import ProcessingPool

# %%
# %%capture capt 
# logging draculab version used for this session
print('======================================================')
print('| kWTA_ei_mp is currently using this draculab commit: |')
print('======================================================')
# !git log -1 --oneline --color=never

# %%
# Write the output of the cell above in the simulation log
with open('kWTA_ei_mp_simlog.txt', 'a') as f:
    f.write(capt.stdout)
    f.close()

# %%
class ei_net():
    def __init__(self, net_number=None):
        # net_number is an optional number assigned by the mp_ei class
        # The history list will store strings containing the instructions doing parameter changes, 
        # building the network, or running a simulation.
        self.history = ["__init__ at " + time.ctime()]
        self.net_number = net_number
        if net_number:
            self.history.append('mp_ei assigned the ei_net object the number ' + str(net_number))
            
        """ All the default parameter dictionaries are below. 
            Time units are seconds for compatibility with the pendulum model.
            Length units for geometry dictionaries are centimeters.
            Axonal conduction speed is ~1 m/s, synaptic delay about 1 ms, but 5 ms for the population response.
        """
        # parameter dictionary for the network
        self.net_params = {'min_delay' : 0.005, # notice delays below are set using this value
                           'min_buff_size' : 10,
                           'rtol' : 1e-5,
                           'atol' : 1e-5 } 
        # parameter dictionary for the excitatory units
        self.unit_pars = {'init_val' : 0.5, 
                          'slope' : 2.,
                          'thresh' : 1.,
                          'tau' : 0.02,  # 20 ms time constant
                          'tau_fast' : 0.04, # 40 ms for fast low-pass filter
                          'tau_slow' : .5, # 500 ms for slow low-pass filter
                          'type' : unit_types.sigmoidal }
        # geometry dictionary for excitatory population
        self.exc_geom = {'shape':'sheet', 
                     'extent':[1.,1.], # 1 square centimeter grid
                     'center':[0.,0.], 
                     'arrangement':'grid', 
                     'rows':20, 
                     'columns':20,  # 400 units
                     'jitter' : 0.02 }
        # geometry dictionary for inhibitory population (keep extent and center same as above)
        self.inh_geom = {'shape':'sheet', 
                     'extent':[1.,1.], 
                     'center':[0.,0.], 
                     'arrangement':'grid', 
                     'rows':10, 
                     'columns':10,  # 100 units
                     'jitter' : 0.02 }
        # parameters for the inhibitory units
        self.inh_pars = {'init_val' : 0.5, 
                         'slope' : 4.,
                         'thresh' : .5,
                         'tau' : 0.04, # 40 ms time constant
                         'tau_fast' : 0.04,
                         'tau_slow' : .5,
                         'type' : unit_types.sigmoidal } 
        # parameters for the input units
        self.n_units = {'inp' : 5} # number of input units
        self.inp_pars = {'type' : unit_types.source,
                         'init_val' : 0.,
                         'tau_fast' : 0.04,
                         'function' : lambda x: None }
        # E-E connections
        self.e2e_conn = {'connection_type' : 'convergent',
            'mask' : {'circular': {'radius': 0.1}},
            'kernel' : 1., #{'gaussian' : {'p_center' : 1.1, 'sigma' : 0.3} },
            'delays' : {'linear' : {'c' : self.net_params['min_delay'], 'a' : 10.}},
            'weights' : {'linear' : {'c' : 0.3, 'a' : 0.1}},
            #'number_of_connections' : 6,
            'allow_autapses' : True,
            'allow_multapses' : False,
            'edge_wrap' : True,
            'boundary' : {'center': np.array(self.exc_geom['center']), 'extent' : self.exc_geom['extent']} }
        self.e2e_syn = {'type' : synapse_types.static,
                        'lrate' : 0.05 }
        # E-I connections
        self.e2i_conn = {'connection_type' : 'convergent',
            'mask' : {'annular': {'inner_radius': 0.1, 'outer_radius': 0.4}},
            'kernel' : {'linear': {'c': 1.1, 'a': 2.5}},
            'delays' : {'linear' : {'c' : self.net_params['min_delay'], 'a' : 10.}},
            'weights' : {'linear' : {'c' : 0.1, 'a' : 0.02}},
            #'number_of_connections' : 14,
            'edge_wrap' : True,
            'boundary' : {'center': np.array(self.inh_geom['center']), 'extent' : self.inh_geom['extent']} }
        self.e2i_syn = {'type' : synapse_types.static,
                        'lrate' : 0.05 }
        # I-E connections
        self.i2e_conn = {'connection_type' : 'convergent',
            'mask' :  {'circular': {'radius': 0.2}},
            'kernel' : 1,
            'delays' : {'linear' : {'c' : self.net_params['min_delay'], 'a' : 10.}},
            'weights' : {'linear' : {'c' : -.1, 'a' : 0.001}},
            'edge_wrap' : True,
            'boundary' : {'center': np.array(self.exc_geom['center']), 'extent' : self.exc_geom['extent']} }
        self.i2e_syn = {'type' : synapse_types.homeo_inh,
            'lrate' : 0.1,
            'des_act' : 0.3 }
        # I-I connections
        self.i2i_conn = {'connection_type' : 'convergent',
            'mask' : {'circular': {'radius': 0.3}},
            'kernel' : 0.5,
            'delays' : {'linear' : {'c' : self.net_params['min_delay'], 'a' : 10.}},
            'weights' : {'linear' : {'c' : -.1, 'a' : 0.001}},
            'edge_wrap' : True,
            'boundary' : {'center': np.array(self.inh_geom['center']), 'extent' : self.inh_geom['extent']} }
        self.i2i_syn = {'type' : synapse_types.homeo_inh,
            'lrate' : 0.1,
            'des_act' : 0.3 }
        # inputs to E and I
        self.i2u_conn_spec = {'rule' : 'all_to_all',
                 'delay' : self.net_params['min_delay'] }
        self.i2u_syn_spec = {'type' : synapse_types.bcm,
                'lrate' : 0.05,
                'init_w' : {'distribution' : 'equal_norm', 'norm' : 1.} }
        self.notes = '' # comments after visualizing simulation results
        # fixing random seed
        seed = 19680801
        np.random.seed(seed)
        # I also use the 'random' module, so I should also run random.seed(seed).
        self.history.append('np.random.seed = ' + str(seed))
        
        
    def build(self):
        """ Create the draculab network. """
        # store record of network being built
        self.history.append('build()')
        # Set derived parameters
        self.e2e_conn['delays'] = {'linear' : {'c' : self.net_params['min_delay'], 'a' : 0.1}}
        self.e2i_conn['delays'] = {'linear' : {'c' : self.net_params['min_delay'], 'a' : 0.1}}
        self.i2e_conn['delays'] = {'linear' : {'c' : self.net_params['min_delay'], 'a' : 0.1}}
        self.i2u_conn_spec['delay'] = self.net_params['min_delay']
        self.e2e_conn['boundary'] = {'center': np.array(self.exc_geom['center']), 'extent' : self.exc_geom['extent']}
        self.e2i_conn['boundary'] = {'center': np.array(self.inh_geom['center']), 'extent' : self.inh_geom['extent']}
        self.i2e_conn['boundary'] = {'center': np.array(self.exc_geom['center']), 'extent' : self.exc_geom['extent']}
        # Create an auxiliary topology object
        topo = topology()
        # Create network
        self.net = network(self.net_params)
        # Create excitatory population
        self.units = topo.create_group(self.net, self.exc_geom, self.unit_pars)
        # Create group of inhibitory units
        self.inh = topo.create_group(self.net, self.inh_geom, self.inh_pars)
        # Create input units
        self.inp = self.net.create(self.n_units['inp'], self.inp_pars)
        # E-E connections
        topo.topo_connect(self.net, self.units, self.units, self.e2e_conn, self.e2e_syn)
        # E-I connections
        topo.topo_connect(self.net, self.units, self.inh, self.e2i_conn, self.e2i_syn)
        # I-E connections
        topo.topo_connect(self.net, self.inh, self.units, self.i2e_conn, self.i2e_syn)
        # I-I connections
        topo.topo_connect(self.net, self.inh, self.inh, self.i2i_conn, self.i2i_syn)
        # Connect the inputs to the units
        self.net.connect(self.inp, self.units, self.i2u_conn_spec, self.i2u_syn_spec)
        self.net.connect(self.inp, self.inh, self.i2u_conn_spec, self.i2u_syn_spec)
        
    def set_param(self, dictionary, entry, value):
        """ Change a value in a parameter dictionary. 
        
            dictionary: a string with the name of one of the parameter dictionaries in __init__
            entry: a string with the name of the entry we'll modify
            value: the value we'll assign (can be any appropriate Python object) 
        """
        if 'build()' in self.history:
            raise AssertionError('Setting a parameter value after network has been built')     
        self.__getattribute__(dictionary)[entry] = value  # set the new value
        self.history.append(dictionary + '[\'' + entry + '\'] = ' + str(value) ) # record assignment
            
    def make_sin_pulse(self, t_init, t_end, per, amp): 
        """ This function returns a function implementing a localized sinusoidal bump(s). """
        return lambda t : amp * ( np.sqrt( 0.5 * (1. + 
                      np.sin( np.pi*( 2.*(t - t_init)/per - 0.5 ) ) ) ) ) #if (t_init < t and t < t_end) else 0.

    def input_vector(self):
        """This function returns an input vector. Different distributions can be implemented with this. """
        # right now it's just random vectors with unit norm
        vec = np.random.uniform(0., 1., self.n_units['inp'])
        return  vec / np.linalg.norm(vec)
        
    def run(self, n_pres, pres_time, alpha=0.3):
        """ Run a simulation, presenting n_pres patterns, each lasting pres_time. 
            
            The argument alpha determines how fast the input amplitudes drift.
            
            Updates:
                self.all_times: 1-D numpy array with the times for each data point in all_activs.
                self.all_activs: 2-D numpy array with the activity of all units at each point in all_times. 
        """
        # store a record of this simulation
        self.history.append('run(' + str(n_pres) + ',' + str(pres_time) + ',' + str(alpha) + ')') 
        # initialize storage of results
        self.all_times = []
        self.all_activs = []
        start_time = time.time()
        inp_vel = np.zeros(self.n_units['inp']) # initial velocity for the input drift
        inp_vec = self.input_vector() # initial amplitudes of the inputs
        # present input patterns
        for pres in range(n_pres):
            print('Simulating presentation ' + str(pres) + ' at network ' + str(self.net_number), end='\r')
            pres_start = time.time()
            t = self.net.sim_time
            inp_accel = self.input_vector() # having an acceleration confers "momentum" to the input drift
            inp_vel = (1.-alpha)*inp_vel + alpha*inp_accel 
            inp_vec = (1.-alpha)*inp_vec + alpha*inp_vel
            for i in self.inp:
                self.net.units[i].set_function(self.make_sin_pulse(t, t+pres_time, pres_time, inp_vec[i-self.inp[0]]))
        
            times, activs, plants = self.net.run(pres_time)
            self.all_times.append(times)
            self.all_activs.append(activs)
            print('Presentation %s lasted %s seconds at network %d.' % (pres, time.time() - pres_start, self.net_number), end='\n')

        self.all_times = np.concatenate(self.all_times)
        self.all_activs = np.concatenate(self.all_activs, axis=1)
        print('Network %d finished executing in %s seconds' % (self.net_number, time.time() - start_time)) 
        return self # see rant on multiprocessing
        
    def basic_plot(self):
        #%matplotlib inline
        inp_fig = plt.figure(figsize=(10,5))
        inputs = np.transpose([self.all_activs[i] for i in self.inp])
        plt.plot(self.all_times, inputs, linewidth=1, figure=inp_fig)
        plt.title('Inputs')

        unit_fig = plt.figure(figsize=(10,5))
        some_acts = np.transpose(self.all_activs[[self.units[i] for i in [0,1,-1,-2]]])
        plt.plot(self.all_times, some_acts, figure=unit_fig)
        plt.title('Some unit activities')

        inh_fig = plt.figure(figsize=(10,5))
        some_inh = np.transpose(self.all_activs[[self.inh[i] for i in [0,1,-1,-2]]])
        plt.plot(self.all_times, some_inh, figure=inh_fig)
        plt.title('some inhibitory units')

        plt.show()
        
    def activ_anim(self, thr, slider=False):
        """ An animation to visualize the activity of the excitatory units. 
        
            Units whose activity surpasses 'thr' will be highlighted.
            It is assumed that this import statement has happened:
            from matplotlib.animation import FuncAnimation
        """
        # %matplotlib qt5
        # notebook or qt5 

        self.unit_fig = plt.figure(figsize=(7,7))
        self.ax = self.unit_fig.add_axes([0, 0, 1, 1], frameon=False)
        self.ax.set_xlim(-1, 1), self.ax.set_xticks([])
        self.ax.set_ylim(-1, 1), self.ax.set_yticks([])
        xcoords = [ u.coordinates[0] for u in [self.net.units[i] for i in self.units] ]
        ycoords = [ u.coordinates[1] for u in [self.net.units[i] for i in self.units] ]
        self.scat = self.ax.scatter(xcoords, ycoords, s=20.*self.all_activs[self.units,0])
        self.n_data = len(self.all_activs[0])
        self.act_thr = thr
        
        if not slider:
            animation = FuncAnimation(self.unit_fig, self.update_act_anim, 
                                  interval=100, save_count=int(round(self.net.sim_time/self.net.min_delay)))    
            return animation
        else:
            from ipywidgets import interact
            widget = interact(self.update_act_anim, frame=(1,self.n_data))
            return widget
        
    def color_fun(self, activ):
        # given the units activity, maps into a color. activ may be an array.
        activ =  np.maximum(0.1,  activ*np.maximum(np.sign(activ - 0.8), 0.))
        return np.outer(activ, np.array([0., .5, 1., .5]))

    def update_act_anim(self, frame):
        # Each frame advances one simulation step (min_delay time units)
        idx = frame%self.n_data
        cur_time = self.net.min_delay*idx
        self.scat.set_sizes(300.*self.all_activs[self.units,idx])
        self.scat.set_color(self.color_fun(self.all_activs[self.units,idx]))
        self.unit_fig.suptitle('Time: ' + '{:f}'.format(cur_time))
        return self.ax,

    def conn_anim(self, source, sink, interv=100):
        """ An animation to visualize the connectivity of Exc. and Inh. populations. 
    
            source and sink are lists with the IDs of the units whose connections we'll
            visualize. Each frame of the animation shows: for a particular unit in source,
            all the neurons in sink that receive connections from it (left plot), and for 
            a particular unit in sink, all the units in source that send it connections
            (right plot).
        
            interv is the refresh interval (in ms) used by FuncAnimation 
        
            It is assumed that this import statement has happened:
            from matplotlib.animation import FuncAnimation
        """
        # %matplotlib qt5
        # notebook or qt5 
        
        # update_conn_anim uses these values
        self.len_source = len(source)
        self.len_sink = len(sink)
        self.source_0 = source[0]
        self.sink_0 = sink[0]

        # flattening net.syns, leaving only the source-sink connections 
        self.all_syns = []
        for syn_list in [self.net.syns[i] for i in sink]:
            syn_list = [s for s in syn_list if s.preID in source]
            self.all_syns += syn_list
    
        # getting lists with the coordinates of all source, sink units
        source_coords = [u.coordinates for u in [self.net.units[i] for i in source]]
        sink_coords = [u.coordinates for u in [self.net.units[i] for i in sink]]
        source_x = [c[0] for c in source_coords]
        source_y = [c[1] for c in source_coords]
        sink_x = [c[0] for c in sink_coords]
        sink_y = [c[1] for c in sink_coords]

        # setting colors
        self.std_src = [0., 0.5, 0.1, 0.5]
        self.std_snk = [1., 0.5, 0.5, 0.5]
        self.big_src = [0., 0., 0., 1.]
        self.big_snk = [0., 1., 0., 1.]

        # constructing figure, axes, path collections
        self.conn_fig = plt.figure(figsize=(9,5))
        self.ax1 = self.conn_fig.add_axes([0.0, 0.01, .49, 0.95], frameon=True, aspect=1)
        self.ax2 = self.conn_fig.add_axes([0.51, 0.01, .49, 0.95], frameon=True, aspect=1)
        self.src_col1 = self.ax1.scatter(source_x, source_y, s=2, c=self.std_src)
        self.snk_col1 = self.ax1.scatter(sink_x, sink_y, s=2, c=self.std_snk)
        self.src_col2 = self.ax2.scatter(source_x, source_y, s=2, c=self.std_src)
        self.snk_col2 = self.ax2.scatter(sink_x, sink_y, s=2, c=self.std_snk)
        self.ax1.set_title('sent connections')
        self.ax2.set_title('received connections')
        self.ax2.set_yticks([])
        
        animation = FuncAnimation(self.conn_fig, self.update_conn_anim, interval=interv, blit=True)
        return animation
    
    def print_conn_numbers(self):
        """ print average number of connections of each type. """
        sum_ee = 0 # number of e-e connections
        sum_ei = 0
        sum_ie = 0
        sum_ii = 0
        sum_pe = 0 # number of input to exc connections
        sum_pi = 0
        for syn_list in self.net.syns:
            for syn in syn_list:
                if syn.postID in self.units:
                    if syn.preID in self.units:
                        sum_ee += 1
                    elif syn.preID in self.inh:
                        sum_ie += 1
                    else:
                        sum_pe += 1
                elif syn.postID in self.inh:
                    if syn.preID in self.units:
                        sum_ei += 1
                    elif syn.preID in self.inh:
                        sum_ii += 1
                    else:
                        sum_pi += 1
        print("Average number of incoming EE connections: %f" % (sum_ee/len(self.units)))
        print("Average number of incoming EI connections: %f" % (sum_ei/len(self.inh)))
        print("Average number of incoming IE connections: %f" % (sum_ie/len(self.units)))
        print("Average number of incoming II connections: %f" % (sum_ii/len(self.inh)))
        print("Average number of incoming inp-E connections: %f" % (sum_pe/len(self.units)))
        print("Average number of incoming inp-I connections: %f" % (sum_pi/len(self.inh)))

    def update_conn_anim(self, frame): 
        sou_u = frame%self.len_source # source unit whose receivers we'll visualize
        snk_u = frame%self.len_sink # sink unit whose senders we'll visualize
    
        # PLOTTING THE RECEIVERS OF sou_u ON THE LEFT AXIS
        source_sizes = np.tile(2, self.len_source)
        sink_sizes = np.tile(2, self.len_sink)
        source_colors = np.tile(self.std_src,(self.len_source,1))
        sink_colors = np.tile(self.std_snk, (self.len_sink,1))
        source_sizes[sou_u] = 30
        source_colors[sou_u] = self.big_src
        # getting targets of projections from the unit 'sou_u'
        targets = [syn.postID - self.sink_0 for syn in self.all_syns if syn.preID == sou_u + self.source_0]
        # setting the colors and sizes
        sink_colors[targets] = self.big_snk
        sink_sizes[targets] = 15
        self.src_col1.set_sizes(source_sizes)
        #ax1.get_children()[0].set_sizes(source_sizes)   # sizes for the source units
        self.snk_col1.set_sizes(sink_sizes)   
        self.src_col1.set_color(source_colors)
        self.snk_col1.set_color(sink_colors)
        
        # PLOTTING THE SENDERS TO snk_u ON THE RIGHT AXIS
        source_sizes = np.tile(2, self.len_source)
        sink_sizes = np.tile(2, self.len_sink)
        source_colors = np.tile(self.std_src, (self.len_source,1))
        sink_colors = np.tile(self.std_snk, (self.len_sink,1))
        sink_sizes[snk_u] = 30
        sink_colors[snk_u] = self.big_snk
        # getting senders of projections to the unit 'snk_u'
        senders = [syn.preID - self.source_0 for syn in self.all_syns if syn.postID == snk_u + self.sink_0]
        # setting the colors and sizes
        source_colors[senders] = self.big_src
        source_sizes[senders] = 15
        self.src_col2.set_sizes(source_sizes)
        self.snk_col2.set_sizes(sink_sizes)   
        self.src_col2.set_color(source_colors)
        self.snk_col2.set_color(sink_colors)
    
        return self.ax1, self.ax2,
    
    def annotate(self, string, make_history=True):
        """ Append a string to self.notes and self.history. """
        self.notes += '# NOTE: ' + string + '\n'
        if make_history:
            self.history.append(string)
            
    def log(self, name="kWTA_ei_mp_simlog.txt"):
        with open(name, 'a') as f:
            f.write('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n')
            f.write('------- Logging ei_net object ' + str(self.net_number) + '------\n')
            f.write('HISTORY \n')
            for entry in self.history:
                f.write(entry + '\n')
            f.write('NOTES \n')
            f.write(self.notes)
            f.write('\n')
            f.close()
        
    def save(self, name="kWTA_ei_mp_pickled.pkl"):
        """ Saving simulation results. 
            A draculab network contains lists with functions, so it is not picklable. 
            But it can be serialized with dill: https://github.com/uqfoundation/dill 
            
            After saving, retrieve object using, for example:
            F = open("kWTA_ei_mp_pickled.pkl", 'rb')
            ei = dill.load(F)
            F.close()
        """
        self.history.append('ei_sim object being saved as ' + name)
        F = open(name, 'wb')
        dill.dump(self, F)
        F.close()

# %%
""" Running multiprocess parameter exploration. """

class mp_ei():
    def __init__(self):
        self.name = 'mp_ei_all_or_nothing'
        self.n_procs = 4
        self.n_nets = 10
        self.n_pres = [20, 20, 20, 20, 20, 20, 20, 40, 20, 20]  # number of presentations for each net
        self.t_pres = [.2, .1, .5, .2, .2, .2, .2, .2, .2, .2]  # duration of presentations for each net
        self.ei_nets = [ei_net(i) for i in range(self.n_nets)]
        
        # Setting the parameter changes for all networks
        ## First, set baseline changes
        for idx, ei in enumerate(self.ei_nets):
            ei.annotate('This is network ' + str(idx) + ' in a run of an mp_ei object called ' + self.name)
            ei.annotate('This set of runs explores the all-or-none activation of the network.')
            #ei.set_param('exc_geom', 'rows', 25)
            #ei.set_param('exc_geom', 'columns', 25)
        ## Now adjust networks individually
        ### network 0 is the baseline
        ### network 1
        self.ei_nets[1].annotate('This network has a shorter presentation time.')
        ### network 2
        self.ei_nets[2].annotate('This network has a longer presentation time.')
        ### network 3
        self.ei_nets[3].annotate('This network replaces the homeo_inh synapses for corr_inh.')
        self.ei_nets[3].set_param('i2e_syn', 'type', synapse_types.corr_inh)
        self.ei_nets[3].set_param('i2i_syn', 'type', synapse_types.corr_inh)
        ### Network 4
        self.ei_nets[4].annotate('This network uses BCM synapses in the E-E connections.')
        self.ei_nets[4].set_param('e2e_syn', 'type', synapse_types.bcm)
        ### Network 5
        self.ei_nets[5].annotate('This network uses BCM synapses in the E-E and E-I connections.')
        self.ei_nets[5].set_param('e2e_syn', 'type', synapse_types.bcm)
        self.ei_nets[5].set_param('e2i_syn', 'type', synapse_types.bcm)
        ### Network 6
        self.ei_nets[6].annotate('This network has faster time constants for the units.')
        self.ei_nets[6].set_param('unit_pars', 'tau', 0.01)
        self.ei_nets[6].set_param('unit_pars', 'tau_fast', 0.02)
        self.ei_nets[6].set_param('inh_pars', 'tau', 0.02)
        self.ei_nets[6].set_param('inh_pars', 'tau_fast', 0.02)
        ### Network 7
        self.ei_nets[7].annotate('This network has slower learning rates and more presentations.')
        self.ei_nets[7].set_param('i2e_syn', 'lrate', 0.05)
        self.ei_nets[7].set_param('i2i_syn', 'lrate', 0.05)
        self.ei_nets[7].set_param('i2u_syn_spec', 'lrate', 0.03)
        ### Network 8
        self.ei_nets[8].annotate('This network has more input units.')
        self.ei_nets[8].set_param('n_units', 'inp', 10)
        ### Network 9
        self.ei_nets[9].annotate('This network has fewer input units.')
        self.ei_nets[9].set_param('n_units', 'inp', 1)

        # Building the networks
        for ei_obj in self.ei_nets:
            ei_obj.build()
        
    def run_net(self, net_num):
        print('Running network %d' % (net_num))
        return self.ei_nets[net_num].run(self.n_pres[net_num], self.t_pres[net_num])
    
    def run_all(self, save=True, log=True):
        pool = ProcessingPool(nodes=self.n_procs) 
        print('Starting %d processes, %d networks' % (self.n_procs, self.n_nets))
        start_time = time.time()
        self.ei_nets = pool.map(self.run_net, range(self.n_nets))
        print('Processing finished after %s seconds' % (time.time() - start_time)) 
        #pool.close()
        #pool.join()
        if save:
            for ei in self.ei_nets:
                ei.history.append('ei_sim object being saved in container mp_ei object ' + self.name)
            F = open(self.name+'.pkl', 'wb')
            dill.dump(self, F)
            F.close()
        if log:
            for ei in self.ei_nets:
                ei.log()

# %%
""" Instantiate mp_ei class and run simulations. """
mp_ei_obj = mp_ei()
mp_ei_obj.run_all()
# Out:
# Starting 4 processes, 10 networks
# Running network 0
# Presentation 0 lasted 11.364112615585327 seconds at network 0.
# Presentation 1 lasted 10.408735275268555 seconds at network 0.
# Running network 1
# Presentation 0 lasted 6.663690567016602 seconds at network 1.
# Presentation 2 lasted 11.560498237609863 seconds at network 0.
# Presentation 1 lasted 6.045063257217407 seconds at network 1.
# Presentation 2 lasted 5.851061105728149 seconds at network 1.
# Presentation 3 lasted 13.800933599472046 seconds at network 0.
# Presentation 3 lasted 6.3499274253845215 seconds at network 1.
# Running network 2
# Presentation 4 lasted 6.430736541748047 seconds at network 1.
# Presentation 4 lasted 16.85356092453003 seconds at network 0.
# Presentation 5 lasted 6.658749341964722 seconds at network 1.
# Presentation 6 lasted 6.9678955078125 seconds at network 1.
# Presentation 5 lasted 12.766324043273926 seconds at network 0.
# Presentation 7 lasted 7.64696192741394 seconds at network 1.
# Running network 3
# Presentation 0 lasted 29.8763108253479 seconds at network 2.
# Presentation 8 lasted 9.701975107192993 seconds at network 1.
# Presentation 6 lasted 21.01227378845215 seconds at network 0.
# Presentation 9 lasted 10.658886909484863 seconds at network 1.
# Presentation 0 lasted 17.336506128311157 seconds at network 3.
# Presentation 10 lasted 7.569478750228882 seconds at network 1.
# Presentation 1 lasted 15.008763074874878 seconds at network 3.
# Presentation 7 lasted 16.654688119888306 seconds at network 0.
# Presentation 11 lasted 9.567442893981934 seconds at network 1.
# Presentation 12 lasted 8.864954471588135 seconds at network 1.
# Presentation 1 lasted 42.393635511398315 seconds at network 2.
# Presentation 2 lasted 14.264076232910156 seconds at network 3.
# Presentation 8 lasted 16.359931230545044 seconds at network 0.
# Presentation 13 lasted 8.648259401321411 seconds at network 1.
# Presentation 3 lasted 14.981247186660767 seconds at network 3.
# Presentation 14 lasted 10.144398927688599 seconds at network 1.
# Presentation 9 lasted 16.532843589782715 seconds at network 0.
# Presentation 15 lasted 7.760798215866089 seconds at network 1.
# Presentation 16 lasted 7.4701268672943115 seconds at network 1.
# Presentation 4 lasted 18.238707304000854 seconds at network 3.
# Presentation 10 lasted 16.403775215148926 seconds at network 0.
# Presentation 2 lasted 40.26186537742615 seconds at network 2.
# Presentation 17 lasted 8.377516508102417 seconds at network 1.
# Presentation 5 lasted 13.091723680496216 seconds at network 3.
# Presentation 18 lasted 9.205207347869873 seconds at network 1.
# Presentation 11 lasted 16.35311770439148 seconds at network 0.
# Presentation 19 lasted 10.071868896484375 seconds at network 1.
# Network 1 finished executing in 160.67762565612793 seconds
# Presentation 6 lasted 16.813411951065063 seconds at network 3.
# Running network 4
# Presentation 12 lasted 20.20063543319702 seconds at network 0.
# Presentation 3 lasted 43.92372441291809 seconds at network 2.
# Presentation 0 lasted 16.02380919456482 seconds at network 4.
# Presentation 7 lasted 19.45561122894287 seconds at network 3.
# Presentation 13 lasted 18.032546997070312 seconds at network 0.
# Presentation 1 lasted 15.058165311813354 seconds at network 4.
# Presentation 8 lasted 19.939125537872314 seconds at network 3.
# Presentation 14 lasted 21.422149419784546 seconds at network 0.
# Presentation 2 lasted 13.521586894989014 seconds at network 4.
# Presentation 9 lasted 17.540613889694214 seconds at network 3.
# Presentation 3 lasted 13.415283203125 seconds at network 4.
# Presentation 15 lasted 14.425704956054688 seconds at network 0.
# Presentation 4 lasted 43.694112062454224 seconds at network 2.
# Presentation 10 lasted 14.980531930923462 seconds at network 3.
# Presentation 4 lasted 16.539736032485962 seconds at network 4.
# Presentation 16 lasted 19.81367826461792 seconds at network 0.
# Presentation 11 lasted 17.66417384147644 seconds at network 3.
# Presentation 5 lasted 14.176181077957153 seconds at network 4.
# Presentation 17 lasted 16.192595720291138 seconds at network 0.
# Presentation 5 lasted 38.97458267211914 seconds at network 2.
# Presentation 12 lasted 15.480359077453613 seconds at network 3.
# Presentation 6 lasted 19.212364435195923 seconds at network 4.
# Presentation 18 lasted 18.542401552200317 seconds at network 0.
# Presentation 13 lasted 17.70120620727539 seconds at network 3.
# Presentation 7 lasted 12.153095483779907 seconds at network 4.
# Presentation 19 lasted 19.04969048500061 seconds at network 0.
# Network 0 finished executing in 327.77348017692566 seconds
# Presentation 8 lasted 13.633587837219238 seconds at network 4.
# Presentation 14 lasted 16.877676486968994 seconds at network 3.
# Running network 5
# Presentation 6 lasted 44.64375853538513 seconds at network 2.
# Presentation 15 lasted 20.08829426765442 seconds at network 3.
# Presentation 9 lasted 23.74447202682495 seconds at network 4.
# Presentation 0 lasted 16.631218433380127 seconds at network 5.
# Presentation 1 lasted 13.890826940536499 seconds at network 5.
# Presentation 10 lasted 16.706718683242798 seconds at network 4.
# Presentation 16 lasted 20.820483207702637 seconds at network 3.
# Presentation 2 lasted 13.498846769332886 seconds at network 5.
# Presentation 7 lasted 49.211992025375366 seconds at network 2.
# Presentation 11 lasted 20.323310136795044 seconds at network 4.
# Presentation 17 lasted 17.90010094642639 seconds at network 3.
# Presentation 3 lasted 13.721319198608398 seconds at network 5.
# Presentation 12 lasted 12.289899587631226 seconds at network 4.
# Presentation 18 lasted 16.986905813217163 seconds at network 3.
# Presentation 4 lasted 18.141995429992676 seconds at network 5.
# Presentation 13 lasted 16.034878969192505 seconds at network 4.
# Presentation 19 lasted 16.287951946258545 seconds at network 3.
# Network 3 finished executing in 341.4819083213806 seconds
# Presentation 5 lasted 14.330811977386475 seconds at network 5.
# Presentation 8 lasted 43.36717438697815 seconds at network 2.
# Running network 6
# Presentation 14 lasted 17.7541561126709 seconds at network 4.
# Presentation 6 lasted 20.0981547832489 seconds at network 5.
# Presentation 0 lasted 15.990203619003296 seconds at network 6.
# Presentation 15 lasted 20.6897394657135 seconds at network 4.
# Presentation 7 lasted 15.681666612625122 seconds at network 5.
# Presentation 1 lasted 15.646093368530273 seconds at network 6.
# Presentation 16 lasted 19.031178951263428 seconds at network 4.
# Presentation 8 lasted 15.192945003509521 seconds at network 5.
# Presentation 2 lasted 15.556188106536865 seconds at network 6.
# Presentation 9 lasted 51.12079858779907 seconds at network 2.
# Presentation 17 lasted 17.264098644256592 seconds at network 4.
# Presentation 9 lasted 20.725356340408325 seconds at network 5.
# Presentation 3 lasted 20.86518096923828 seconds at network 6.
# Presentation 18 lasted 17.556162357330322 seconds at network 4.
# Presentation 10 lasted 12.400270700454712 seconds at network 5.
# Presentation 4 lasted 16.269840240478516 seconds at network 6.
# Presentation 10 lasted 43.30268669128418 seconds at network 2.
# Presentation 11 lasted 15.576872110366821 seconds at network 5.
# Presentation 19 lasted 16.578030824661255 seconds at network 4.
# Network 4 finished executing in 331.7332112789154 seconds
# Running network 7
# Presentation 5 lasted 19.93810510635376 seconds at network 6.
# Presentation 12 lasted 21.596569299697876 seconds at network 5.
# Presentation 0 lasted 17.701168298721313 seconds at network 7.
# Presentation 6 lasted 25.05165195465088 seconds at network 6.
# Presentation 13 lasted 14.58407187461853 seconds at network 5.
# Presentation 1 lasted 13.821621894836426 seconds at network 7.
# Presentation 7 lasted 15.378756046295166 seconds at network 6.
# Presentation 11 lasted 53.067036151885986 seconds at network 2.
# Presentation 2 lasted 12.291799306869507 seconds at network 7.
# Presentation 14 lasted 19.946315050125122 seconds at network 5.
# Presentation 3 lasted 12.927248001098633 seconds at network 7.
# Presentation 15 lasted 14.497223854064941 seconds at network 5.
# Presentation 8 lasted 21.72546362876892 seconds at network 6.
# Presentation 4 lasted 13.435313701629639 seconds at network 7.
# Presentation 16 lasted 18.231661319732666 seconds at network 5.
# Presentation 9 lasted 20.554221868515015 seconds at network 6.
# Presentation 5 lasted 13.917845487594604 seconds at network 7.
# Presentation 12 lasted 43.16656494140625 seconds at network 2.
# Presentation 17 lasted 15.893828630447388 seconds at network 5.
# Presentation 10 lasted 15.597068786621094 seconds at network 6.
# Presentation 6 lasted 18.138211727142334 seconds at network 7.
# Presentation 18 lasted 18.371214151382446 seconds at network 5.
# Presentation 7 lasted 12.474778652191162 seconds at network 7.
# Presentation 11 lasted 21.342849016189575 seconds at network 6.
# Presentation 13 lasted 42.99044179916382 seconds at network 2.
# Presentation 19 lasted 16.1558780670166 seconds at network 5.
# Network 5 finished executing in 329.19362473487854 seconds
# Presentation 8 lasted 15.229771375656128 seconds at network 7.
# Running network 8
# Presentation 12 lasted 22.81633162498474 seconds at network 6.
# Presentation 9 lasted 20.168333292007446 seconds at network 7.
# Presentation 0 lasted 15.780896425247192 seconds at network 8.
# Presentation 10 lasted 16.335264921188354 seconds at network 7.
# Presentation 13 lasted 25.276930809020996 seconds at network 6.
# Presentation 1 lasted 14.525146245956421 seconds at network 8.
# Presentation 11 lasted 16.03940176963806 seconds at network 7.
# Presentation 2 lasted 15.362696409225464 seconds at network 8.
# Presentation 14 lasted 56.28061270713806 seconds at network 2.
# Presentation 14 lasted 21.68826937675476 seconds at network 6.
# Presentation 12 lasted 17.681211948394775 seconds at network 7.
# Presentation 3 lasted 17.389740467071533 seconds at network 8.
# Presentation 15 lasted 19.037210702896118 seconds at network 6.
# Presentation 13 lasted 14.821792840957642 seconds at network 7.
# Presentation 4 lasted 20.2548246383667 seconds at network 8.
# Presentation 15 lasted 43.55928421020508 seconds at network 2.
# Presentation 16 lasted 21.632304668426514 seconds at network 6.
# Presentation 14 lasted 20.514588117599487 seconds at network 7.
# Presentation 5 lasted 16.846678733825684 seconds at network 8.
# Presentation 15 lasted 13.325321912765503 seconds at network 7.
# Presentation 17 lasted 22.510249376296997 seconds at network 6.
# Presentation 6 lasted 23.054726123809814 seconds at network 8.
# Presentation 16 lasted 20.0566623210907 seconds at network 7.
# Presentation 18 lasted 24.129684448242188 seconds at network 6.
# Presentation 16 lasted 48.77853202819824 seconds at network 2.
# Presentation 7 lasted 17.31069564819336 seconds at network 8.
# Presentation 17 lasted 15.93377685546875 seconds at network 7.
# Presentation 19 lasted 22.63506555557251 seconds at network 6.
# Network 6 finished executing in 403.66394782066345 seconds
# Presentation 8 lasted 21.0907564163208 seconds at network 8.
# Presentation 18 lasted 18.341499090194702 seconds at network 7.
# Running network 9
# Presentation 9 lasted 16.958104133605957 seconds at network 8.
# Presentation 0 lasted 11.17687702178955 seconds at network 9.
# Presentation 19 lasted 16.156010389328003 seconds at network 7.
# Presentation 17 lasted 44.68040370941162 seconds at network 2.
# Presentation 1 lasted 10.188180208206177 seconds at network 9.
# Presentation 20 lasted 19.002166986465454 seconds at network 7.
# Presentation 10 lasted 21.883806705474854 seconds at network 8.
# Presentation 2 lasted 10.69311261177063 seconds at network 9.
# Presentation 3 lasted 11.319168090820312 seconds at network 9.
# Presentation 21 lasted 15.412358522415161 seconds at network 7.
# Presentation 11 lasted 17.086117267608643 seconds at network 8.
# Presentation 18 lasted 44.43873405456543 seconds at network 2.
# Presentation 4 lasted 16.068387031555176 seconds at network 9.
# Presentation 22 lasted 20.749642848968506 seconds at network 7.
# Presentation 12 lasted 22.77566432952881 seconds at network 8.
# Presentation 5 lasted 12.324719429016113 seconds at network 9.
# Presentation 23 lasted 14.246159791946411 seconds at network 7.
# Presentation 6 lasted 15.66253113746643 seconds at network 9.
# Presentation 13 lasted 16.741270780563354 seconds at network 8.
# Presentation 7 lasted 11.42776346206665 seconds at network 9.
# Presentation 24 lasted 20.81496238708496 seconds at network 7.
# Presentation 19 lasted 48.01196503639221 seconds at network 2.
# Network 2 finished executing in 895.7709078788757 seconds
# Presentation 14 lasted 23.067179918289185 seconds at network 8.
# Presentation 8 lasted 13.647619247436523 seconds at network 9.
# Presentation 25 lasted 14.375499486923218 seconds at network 7.
# Presentation 9 lasted 13.593710660934448 seconds at network 9.
# Presentation 15 lasted 17.307278633117676 seconds at network 8.
# Presentation 26 lasted 19.7718026638031 seconds at network 7.
# Presentation 10 lasted 13.19142198562622 seconds at network 9.
# Presentation 16 lasted 20.521469354629517 seconds at network 8.
# Presentation 27 lasted 15.756449460983276 seconds at network 7.
# Presentation 11 lasted 15.117945671081543 seconds at network 9.
# Presentation 12 lasted 12.7670578956604 seconds at network 9.
# Presentation 17 lasted 20.052977085113525 seconds at network 8.
# Presentation 28 lasted 17.44088101387024 seconds at network 7.
# Presentation 13 lasted 14.684015274047852 seconds at network 9.
# Presentation 29 lasted 17.389357566833496 seconds at network 7.
# Presentation 18 lasted 17.728498697280884 seconds at network 8.
# Presentation 14 lasted 13.906202793121338 seconds at network 9.
# Presentation 30 lasted 15.24384880065918 seconds at network 7.
# Presentation 19 lasted 21.418104648590088 seconds at network 8.
# Network 8 finished executing in 377.17866230010986 seconds
# Presentation 15 lasted 13.028510332107544 seconds at network 9.
# Presentation 31 lasted 19.5050048828125 seconds at network 7.
# Presentation 16 lasted 16.5460467338562 seconds at network 9.
# Presentation 17 lasted 10.835082530975342 seconds at network 9.
# Presentation 32 lasted 14.546072244644165 seconds at network 7.
# Presentation 18 lasted 15.847916841506958 seconds at network 9.
# Presentation 33 lasted 17.550743579864502 seconds at network 7.
# Presentation 19 lasted 12.666242361068726 seconds at network 9.
# Network 9 finished executing in 264.7160472869873 seconds
# Presentation 34 lasted 16.30230212211609 seconds at network 7.
# Presentation 35 lasted 14.583775520324707 seconds at network 7.
# Presentation 36 lasted 18.328625440597534 seconds at network 7.
# Presentation 37 lasted 14.05210542678833 seconds at network 7.
# Presentation 38 lasted 15.660227298736572 seconds at network 7.
# Presentation 39 lasted 16.53389286994934 seconds at network 7.
# Network 7 finished executing in 656.6274273395538 seconds
# Processing finished after 1224.4358172416687 seconds

# %%
""" Create basic plot """
# %matplotlib inline
mp_ei_obj.ei_nets[5].basic_plot()

# %%
""" Activity animations """
act_ani0 = mp_ei_obj.ei_nets[0].activ_anim(0.8, slider=False)

# %%
""" View the connections. """
mp_ei_obj.ei_nets[0].print_conn_numbers()
conn_ani = mp_ei_obj.ei_nets[0].conn_anim(ei.inh, ei.inh)
# Out:
# Average number of incoming EE connections: 12.455000
# Average number of incoming EI connections: 76.570000
# Average number of incoming IE connections: 12.552500
# Average number of incoming II connections: 14.050000
# Average number of incoming inp-E connections: 5.000000
# Average number of incoming inp-I connections: 5.000000

# %%
""" Running again from the last state. """
# Executing run again overwrites the results from the last simulation.
n_presentations = 5
t_presentation = 0.15
mp_ei_obj.ei_nets[5].run(n_presentations, t_presentation)
# Out:
# Presentation 0 lasted 11.924759149551392 seconds at network 5.
# Presentation 1 lasted 12.90631365776062 seconds at network 5.
# Presentation 2 lasted 10.606526613235474 seconds at network 5.
# Presentation 3 lasted 12.970175743103027 seconds at network 5.
# Presentation 4 lasted 10.782892227172852 seconds at network 5.
# Network 5 finished executing in 59.19378733634949 seconds

# %%
""" Retrieving a 'dilled' ei_net object and running again. """
F = open("mp_ei_all_or_nothing.pkl", 'rb')
mp_ei_obj = dill.load(F)
F.close()
print('Initial sim_time: ' + str(mp_ei_obj.ei_nets[0].net.sim_time))
# Out:
# Initial sim_time: 3.999999999999937

# %%
mp_ei_obj.run_all()
# Out:
# Starting 4 processes, 10 networks
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.5/pickle.py in _getattribute(obj, name)
#     267             parent = obj
# --> 268             obj = getattr(obj, subpath)
#     269         except AttributeError:
#
# AttributeError: module '__main__' has no attribute 'mp_ei'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/lib/python3.5/pickle.py in save_global(self, obj, name)
#     906             module = sys.modules[module_name]
# --> 907             obj2, parent = _getattribute(module, name)
#     908         except (ImportError, KeyError, AttributeError):
#
# /usr/lib/python3.5/pickle.py in _getattribute(obj, name)
#     270             raise AttributeError("Can't get attribute {!r} on {!r}"
# --> 271                                  .format(name, obj))
#     272     return obj, parent
#
# AttributeError: Can't get attribute 'mp_ei' on <module '__main__'>
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# <ipython-input-4-b56c539a7576> in <module>()
# ----> 1 mp_ei_obj.run_all()
#
# <ipython-input-5-b0c7e535bcde> in run_all(self, save, log)
#
# /usr/local/lib/python3.5/dist-packages/pathos/multiprocessing.py in map(self, f, *args, **kwds)
#     135         AbstractWorkerPool._AbstractWorkerPool__map(self, f, *args, **kwds)
#     136         _pool = self._serve()
# --> 137         return _pool.map(star(f), zip(*args)) # chunksize
#     138     map.__doc__ = AbstractWorkerPool.map.__doc__
#     139     def imap(self, f, *args, **kwds):
#
# /usr/local/lib/python3.5/dist-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# /usr/local/lib/python3.5/dist-packages/multiprocess/pool.py in get(self, timeout)
#     606             return self._value
#     607         else:
# --> 608             raise self._value
#     609
#     610     def _set(self, i, obj):
#
# /usr/local/lib/python3.5/dist-packages/multiprocess/pool.py in _handle_tasks(taskqueue, put, outqueue, pool, cache)
#     383                         break
#     384                     try:
# --> 385                         put(task)
#     386                     except Exception as e:
#     387                         job, ind = task[:2]
#
# /usr/local/lib/python3.5/dist-packages/multiprocess/connection.py in send(self, obj)
#     207         self._check_closed()
#     208         self._check_writable()
# --> 209         self._send_bytes(ForkingPickler.dumps(obj))
#     210
#     211     def recv_bytes(self, maxlength=None):
#
# /usr/local/lib/python3.5/dist-packages/multiprocess/reduction.py in dumps(cls, obj, protocol)
#      51     def dumps(cls, obj, protocol=None):
#      52         buf = io.BytesIO()
# ---> 53         cls(buf, protocol).dump(obj)
#      54         return buf.getbuffer()
#      55
#
# /usr/lib/python3.5/pickle.py in dump(self, obj)
#     406         if self.proto >= 4:
#     407             self.framer.start_framing()
# --> 408         self.save(obj)
#     409         self.write(STOP)
#     410         self.framer.end_framing()
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     738         write(MARK)
#     739         for element in obj:
# --> 740             save(element)
#     741
#     742         if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     723         if n <= 3 and self.proto >= 2:
#     724             for element in obj:
# --> 725                 save(element)
#     726             # Subtle.  Same as in the big comment below.
#     727             if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     723         if n <= 3 and self.proto >= 2:
#     724             for element in obj:
# --> 725                 save(element)
#     726             # Subtle.  Same as in the big comment below.
#     727             if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/local/lib/python3.5/dist-packages/dill-0.2.8.dev0-py3.5.egg/dill/dill.py in save_function(pickler, obj)
#    1353                                 globs, obj.__name__,
#    1354                                 obj.__defaults__, obj.__closure__,
# -> 1355                                 obj.__dict__), obj=obj)
#    1356         else:
#    1357             _super = ('super' in getattr(obj.func_code,'co_names',())) and (_byref is not None) and getattr(pickler, '_recurse', False)
#
# /usr/lib/python3.5/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     597         else:
#     598             save(func)
# --> 599             save(args)
#     600             write(REDUCE)
#     601
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     738         write(MARK)
#     739         for element in obj:
# --> 740             save(element)
#     741
#     742         if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     723         if n <= 3 and self.proto >= 2:
#     724             for element in obj:
# --> 725                 save(element)
#     726             # Subtle.  Same as in the big comment below.
#     727             if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/local/lib/python3.5/dist-packages/dill-0.2.8.dev0-py3.5.egg/dill/dill.py in save_cell(pickler, obj)
#    1096     log.info("Ce: %s" % obj)
#    1097     f = obj.cell_contents
# -> 1098     pickler.save_reduce(_create_cell, (f,), obj=obj)
#    1099     log.info("# Ce")
#    1100     return
#
# /usr/lib/python3.5/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     597         else:
#     598             save(func)
# --> 599             save(args)
#     600             write(REDUCE)
#     601
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     723         if n <= 3 and self.proto >= 2:
#     724             for element in obj:
# --> 725                 save(element)
#     726             # Subtle.  Same as in the big comment below.
#     727             if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/local/lib/python3.5/dist-packages/dill-0.2.8.dev0-py3.5.egg/dill/dill.py in save_instancemethod0(pickler, obj)
#    1045     log.info("Me: %s" % obj) #XXX: obj.__dict__ handled elsewhere?
#    1046     if PY3:
# -> 1047         pickler.save_reduce(MethodType, (obj.__func__, obj.__self__), obj=obj)
#    1048     else:
#    1049         pickler.save_reduce(MethodType, (obj.im_func, obj.im_self,
#
# /usr/lib/python3.5/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     597         else:
#     598             save(func)
# --> 599             save(args)
#     600             write(REDUCE)
#     601
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/lib/python3.5/pickle.py in save_tuple(self, obj)
#     723         if n <= 3 and self.proto >= 2:
#     724             for element in obj:
# --> 725                 save(element)
#     726             # Subtle.  Same as in the big comment below.
#     727             if id(obj) in memo:
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     518
#     519         # Save the reduce() output and finally memoize the object
# --> 520         self.save_reduce(obj=obj, *rv)
#     521
#     522     def persistent_id(self, obj):
#
# /usr/lib/python3.5/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     592                     "args[0] from __newobj__ args has the wrong class")
#     593             args = args[1:]
# --> 594             save(cls)
#     595             save(args)
#     596             write(NEWOBJ)
#
# /usr/lib/python3.5/pickle.py in save(self, obj, save_persistent_id)
#     473         f = self.dispatch.get(t)
#     474         if f is not None:
# --> 475             f(self, obj) # Call unbound method with explicit self
#     476             return
#     477
#
# /usr/local/lib/python3.5/dist-packages/dill-0.2.8.dev0-py3.5.egg/dill/dill.py in save_type(pickler, obj)
#    1269             else:
#    1270                 log.info("T5: %s" % obj)
# -> 1271                 StockPickler.save_global(pickler, obj)
#    1272                 log.info("# T5")
#    1273                 return
#
# /usr/lib/python3.5/pickle.py in save_global(self, obj, name)
#     909             raise PicklingError(
#     910                 "Can't pickle %r: it's not found as %s.%s" %
# --> 911                 (obj, module_name, name))
#     912         else:
#     913             if obj2 is not obj:
#
# PicklingError: Can't pickle <class '__main__.mp_ei'>: it's not found as __main__.mp_ei

# %%
# Out:
# Interactive namespace is empty.
