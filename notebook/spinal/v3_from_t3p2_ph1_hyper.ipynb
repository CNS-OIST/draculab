# %% [markdown]
# # v3_from_t3p2_ph1_hyper.ipynb
#
# Hyperparameter search on the v3_from_t3p2_ph1 model using a genetic algorithm.

# %%
# %cd ../..
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
from datetime import datetime
from multiprocessing import Pool
# Out:
# /home/z/projects/draculab

# %%
# %load_ext Cython

# %%
# %%cython
# from draculab import *

# %%
# %cd /home/z/projects/draculab/notebook/spinal/
from v3ft3p2ph1_net import *
# %cd ../..
# Out:
# /home/z/projects/draculab/notebook/spinal
# /home/z/projects/draculab

# %%
# A method to mutate individual parameters of a configuration
focus_params = False # whether to focus mutations on a specific set of parameters

# Specify paramters and ranges
# defaults are based on incumbent 9 of smac_pars in v3_normal_smac_test.ipynb
ranges = {"A__M_w_max_frac" : {"low": .05, "high": 1., "default":.5},
          "A__M_w_sum" : {"low": 1., "high": 40., "default":2.},
          "A__M_lrate" : {"low": 0.1, "high": 20., "default":5.},
          "b_e": {"low": .5, "high": 10., "default":3.},
          "C__C_scale": {"low": 0., "high": 2.5, "default":1.},
          "C_adapt_amp": {"low": 0., "high": 15., "default":4.},
          "C_cid" : {"low": 0.1, "high": 2., "default":.185},
          #"C_sigma" : {"low": 0., "high": 1., "default":.3}, # C_noise=False
          "C_slope" : {"low": 0.5, "high": 4., "default":.2},
          "C_thresh" : {"low": -0.2, "high": 1.2, "default":.2},
          "g_e_factor": {"low": 0.5, "high": 4., "default":2.3},
          "M__C_lrate" : {"low": 5., "high": 500., "default":300.},
          "M__C_w_sum": {"low": 0.5, "high": 4., "default":1.},
          "M__M_w": {"low": 0., "high": -3., "default":-1.},
          "M_cid": {"low": 0.05, "high": 2., "default": .3},
          "M_des_out_w_abs_sum": {"low": 0.5, "high": 4., "default": 1.6},
          "SPF__SPF_w": {"low": 0., "high": -3., "default":-1.}
         }


#par_list = [name for name in ranges] # ordered list with names of the parameters
par_list = list(ranges.keys())
# parameters to focus on
#main_pars = ["M_thresh", "M_slope", "M__C_lrate", "AF__M_w_sum", "AF__M_lrate", "M_p1_inp"]
if focus_params:
    par_list = main_pars

def mutate(cfg, name_list=par_list):
    """ Mutate a single parameter of the given configuration. 
    
        Args:
            name_list: list with names of candidate parameters.
    """
    n = np.random.randint(len(name_list))
    par_name = name_list[n]
    l = ranges[par_name]['low']
    h = ranges[par_name]['high']
    cfg[par_name] =  l + (h-l)*np.random.random()
    
def soft_mutate(cfg, ma, name_list=par_list):
    """ Soft-mutate a single parameter of the given configuration.
    
        A 'soft mutation' keeps the mutated value close to the original value.
        The maximum amplitude of the mutation is given by the 'ma' argument.
        
        Args:
            ma : float in (0,1]. Max. amplitude as fraction of the parameter's range 
            name_list: list with names of candidate parameters.
    """
    n = np.random.randint(len(name_list))
    par_name = name_list[n]
    l = ranges[par_name]['low']
    h = ranges[par_name]['high']
    cfg[par_name] = max(l, min(h, cfg[par_name] + ma * (h-l) * (np.random.random()-0.5)))

# %%
# Create the initial population: method 1

# create variations of the parameters we want to investigtate
pop_size = 60 # number of configuration in the population
pop = [{} for _ in range(pop_size)]
# first fill the default values in n_def elements
n_def = 3
for ind in range(n_def):
    for name in par_list:
        pop[ind][name] = ranges[name]['default']
        
# fill the rest with variations in both directions
chg_name = ["low", "default", "high"] # auxiliary list
for ind in range(n_def, pop_size):
    chg_dirs = [chg_name[i] for i in np.random.randint(3, size=len(par_list))]
    for idx, name in enumerate(par_list):
        pop[ind][name] = 0.5 * (ranges[name][chg_dirs[idx]] + ranges[name]["default"])
        
# Throw n_muts mutations, and n_soft_muts soft mutations
n_muts = 20
n_soft_muts = 10 # must have n_muts + n_soft_muts < pop_size-1
perm = np.random.permutation(range(1,pop_size)) # don't mutate the first element
for i in range(n_muts):
    mutate(pop[perm[i]])
for i in range(n_muts,n_muts+n_soft_muts):
    soft_mutate(pop[perm[i]], 0.2)

# %% [raw]
# # Create the initial population: method 2
#
# # Load the results from a previous run
# fname = '/home/z/projects/draculab/saves/v3_from_t3p2_ph1_'
# with (open(fname, "rb")) as f:
#     pop = pickle.load(f)
#     f.close()
#
# # If the results are form a run with fewer parameters
# # fill it with the default values.
# for cfg in pop:
#     for name in ranges:
#         if not name in cfg:
#             cfg[name] = ranges[name]['default']

# %%
# reset fitness and number of evaluations
for dic in pop:
    dic['fitness'] = None # average fitness value
    dic['n_evals'] = 0  # number of times fitness has been evaluated
    
# Set search parameters present in the configurations
for cfg in pop:
    cfg['t_pres'] = 40
    cfg['par_heter'] = 0.01

# %%
# print used configuration
for dic in pop[0:3]:
    print('{',end='')
    for name in dic.keys():
        print("\'%s\':%s, "%(name, dic[name]), end='')
#         if name in net_conf:
#             print("\'%s\':%s, "%(name, dic[name]), end='')
#         if name != 'fitness' or dic['fitness'] != None:
#             print("\'%s\':%.2f, " % (name, dic[name]), end='')
    print('}\n')

pop[0]
# Out:
# {'A__M_w_max_frac':0.5, 'A__M_w_sum':2.0, 'A__M_lrate':5.0, 'b_e':3.0, 'C__C_scale':1.0, 'C_adapt_amp':4.0, 'C_cid':0.185, 'C_slope':0.2, 'C_thresh':0.2, 'g_e_factor':2.3, 'M__C_lrate':300.0, 'M__C_w_sum':1.0, 'M__M_w':-1.0, 'M_cid':0.3, 'M_des_out_w_abs_sum':1.6, 'SPF__SPF_w':-1.0, 'fitness':None, 'n_evals':0, 't_pres':40, 'par_heter':0.01, }
#
# {'A__M_w_max_frac':0.5, 'A__M_w_sum':2.0, 'A__M_lrate':5.0, 'b_e':3.0, 'C__C_scale':1.0, 'C_adapt_amp':4.0, 'C_cid':0.185, 'C_slope':0.2, 'C_thresh':0.5320283965408292, 'g_e_factor':2.3, 'M__C_lrate':300.0, 'M__C_w_sum':1.0, 'M__M_w':-1.0, 'M_cid':0.3, 'M_des_out_w_abs_sum':1.6, 'SPF__SPF_w':-1.0, 'fitness':None, 'n_evals':0, 't_pres':40, 'par_heter':0.01, }
#
# {'A__M_w_max_frac':0.5, 'A__M_w_sum':2.0, 'A__M_lrate':5.0, 'b_e':3.0, 'C__C_scale':1.0, 'C_adapt_amp':4.0, 'C_cid':0.185, 'C_slope':0.2, 'C_thresh':0.2, 'g_e_factor':2.3, 'M__C_lrate':300.0, 'M__C_w_sum':1.0, 'M__M_w':-1.0, 'M_cid':0.3, 'M_des_out_w_abs_sum':1.6, 'SPF__SPF_w':-1.0, 'fitness':None, 'n_evals':0, 't_pres':40, 'par_heter':0.01, }
# {'A__M_w_max_frac': 0.5,
#  'A__M_w_sum': 2.0,
#  'A__M_lrate': 5.0,
#  'b_e': 3.0,
#  'C__C_scale': 1.0,
#  'C_adapt_amp': 4.0,
#  'C_cid': 0.185,
#  'C_slope': 0.2,
#  'C_thresh': 0.2,
#  'g_e_factor': 2.3,
#  'M__C_lrate': 300.0,
#  'M__C_w_sum': 1.0,
#  'M__M_w': -1.0,
#  'M_cid': 0.3,
#  'M_des_out_w_abs_sum': 1.6,
#  'SPF__SPF_w': -1.0,
#  'fitness': None,
#  'n_evals': 0,
#  't_pres': 40,
#  'par_heter': 0.01}

# %%
# A function to produce offspring by crossing individuals
par_names = list(pop[0].keys()) # list with all parameter names

def create_offspring(cfg1, cfg2, par_list=par_names):
    """ Given 2 configurations, return 2 offspring from random swapping.
    
        To produce offspring, first we choose one split point in the
        dictionary. The first offspring has the values of cfg1 up to that
        point, and cfg2 afterwards. The second offspring has the cfg2 values
        up to the split point, and cfg1 afterwards. Since the dictionaries are
        not ordered, we use a parameter list to set the split point.
    
        Args:
            cfg1, cfg2: parameter dictionaries
            par_list: list with the keys in cfg1, cfg2
        Returns:
            cfg3, cfg4: dictionaries from swapping values in cfg1, cfg2
    """
    if focus_params:
        par_list = main_pars
    sp = np.random.randint(len(par_list))# split point as an index to par_list
    cfg3 = cfg1.copy()
    cfg4 = cfg2.copy()
    for i in range(sp, len(par_list)):
        cfg3[par_list[i]] = cfg2[par_list[i]]
        cfg4[par_list[i]] = cfg1[par_list[i]]
    return cfg3, cfg4

# visualize
# cfg3, cfg4 = create_offspring(pop[10], pop[11])
# for dic in (pop[10], pop[11], cfg3, cfg4):
#     print('{',end='')
#     for name in par_names:
#         if name != "fitness":
#             print("\'%s\':%.2f, " % (name, dic[name]), end='')
#     print('}\n')

# %%
# A function that evaluates the fitness of a given configuration
def eval_config(cfg):
    """ Returns the error for a network with a given configuration.

        Args:
            cfg : a configuration dictionary.
        Returns:
            error : A float calculated from the sum of activities in the SPF layer.
    """
    np.random.seed() # will try to get a seed from /dev/urandom
    if cfg['n_evals'] > 8: # if the fitness has been evaluated "enough" times. See cell below...
        return cfg['fitness']
    t_pres = cfg['t_pres']
    
    # obtain a network with the given configuration
    net, pops_dict, hand_coords, m_idxs = net_from_cfg(cfg,
               t_pres = cfg['t_pres'], 
               par_heter = cfg['par_heter'],
               set_C_delay = True,
               rand_targets = True,
               C_noise = False,
               track_weights = False,
               track_ips = False)
    # run the network
    run_time = 800.
    #start_time = time.time()
    times, data, plant_data  = net.flat_run(run_time)
    #print('Execution time is %s seconds' % (time.time() - start_time))

    # calculate average error in last half of reaching
    P = pops_dict['P']
    arm_activs = plant_data[P]
    plant = net.plants[P]
    # modified copy-paste of plt.upd_ip_impl
    q1 = arm_activs[:,0]
    q2 = arm_activs[:,2]
    q12 = q1+q2
    c_elbow = np.array((plant.l_arm*np.cos(q1), plant.l_arm*np.sin(q1)))
    c_hand = np.array((c_elbow[0] + plant.l_farm*np.cos(q12),
                    c_elbow[1] + plant.l_farm*np.sin(q12))).transpose()
    coord_idxs = np.floor(times/t_pres).astype(int)
    des_coords = np.array(hand_coords)[m_idxs[coord_idxs],:] # desired coordinates at each moment in time

    error_time = run_time - round(run_time/2.)
    error_idx = int(round(error_time/net.min_delay))
    hand_error = np.linalg.norm(c_hand-des_coords, axis=1)
    hand_error_integ = hand_error[error_idx:].sum()
    avg_hand_error = hand_error_integ / (hand_error.size - error_idx)

    #return hand_error_integ
    return avg_hand_error

# %%
####################################
###### The genetic algorithm ######
####################################

# pop = pop[0:6] # limit pop size for debugging
n_mates = 10 # number of individuals to mate at each generation (even number)
max_gens = 100 # maximum number of generations
n_soft_mut = 6 # numbef of individuals to soft-mutate per generation
r_soft_mut = 0.2 # relative amplitude of soft mutations
n_mut = 6 # number of individuals to mutate per generation
n_procs = 30 # number of processes to use for fitness evaluation
n_save = 3 # number of individuals to protect from replacement and mutation
# setting name for file where parameters will be stored
fname = "v3ft3p2ph1_pop"
fname += "_" + datetime.now().strftime('%Y-%m-%d__%H_%M')

for gen in range(max_gens):
    start_time = time.time()
    # 1) Evaluate fitness
    # 1.1) Do the evaluation
    ######### Single process version
    #fits = list(map(eval_config, pop))
    ######## parallel version
    with Pool(n_procs) as p:
        fits = list(p.map(eval_config, pop))
        p.close()
        p.join()
    #print(fits)
    # 1.2) update the average fitness values
    for idx, cfg in enumerate(pop):
        nr = cfg['n_evals'] # n_evals is not updated yet...
        #print(nr)
        #print(fits[idx])
        #print(cfg['fitness'])
        if nr > 0:
            if nr < 9: # horrible arbitrary number that might be different in eval_config :( 
                cfg['fitness'] = (cfg['fitness']*nr + fits[idx])/(nr+1)
        else:
            cfg['fitness'] = fits[idx]
        cfg['n_evals'] = cfg['n_evals'] + 1
    # 2) Sort according to fitness. Lowest error first.
    pop = sorted(pop, key=lambda d: d['fitness'])
    # 2.1) Save current generation
    with open(fname, 'wb') as f:
        pickle.dump(pop, f)
        f.close()
    # 2.2) A quick message
    print("Generation %d evaluated. Best fitness: %.3f"%(gen,pop[0]['fitness']))
    print("Mean fitness = %.3f"%(np.mean(np.array(fits))))
    # 2.3) If best fitness good enough, break
    if pop[0]['fitness'] < 0.02:
        print("Good enough parameters found. Stopping search.")
        break
    # 3) mate and replace
    # 3.1) Select individuals to be replaced with probability proportional to error
    fits.sort() # sort the fitnesses (now in the same order as pop)
    fits = np.array(fits)
    fits = fits/fits.sum() # normalize fitnesses so they add to 1
    cumsum_fits = fits[:] # cumsum_fits[i] = sum(fits[:i])
    for i in range(1,len(cumsum_fits)):
        cumsum_fits[i] = cumsum_fits[i-1] + cumsum_fits[i]
    repl_list = [] # list with indexes of individuals to be replaced
    while len(repl_list) < n_mates:
        min_r = cumsum_fits[n_save] # don't replace the first n_save individuals
        r = min_r + (1.-min_r) * np.random.random()
        candidate = n_save
        for i in range(n_save, len(fits)):
            if cumsum_fits[i] > r:
                break
            candidate += 1
        if candidate in repl_list:
            continue
        else:
            repl_list.append(candidate)
    print("to replace: ", end='')
    print(repl_list)
    # 3.2) Arrange individuals in random pairs
    perm = np.random.permutation(n_mates) # this will do 
    # 3.3) mate
    new_pops = []
    for i in range(int(np.floor(n_mates/2))):
        off1, off2 = create_offspring(pop[perm[2*i]], pop[perm[2*i+1]])
        new_pops.append(off1)
        new_pops.append(off2)
    # 3.4) replace
    for i, cfg in enumerate(new_pops):
        pop[repl_list[i]] = cfg
    # 4) mutate
    # 4.1) soft mutations
    for _ in range(n_soft_mut):
        idx = np.random.randint(len(pop))
        if idx < n_save:
            copy = pop[idx].copy()
            soft_mutate(copy, r_soft_mut)
            pop[-idx-1] = copy
            pop[-idx-1]['fitness'] = None
            pop[-idx-1]['n_evals'] = 0
        else:
            soft_mutate(pop[idx], r_soft_mut)
            pop[idx]['fitness'] = None
            pop[idx]['n_evals'] = 0
    # 4.2) mutations
    # 4.2.1) select individuals to mutate
    # sq_fits = fits*fits
    #cumsum_sq_fits = fits * fits # cumsum_sq_fits[i] = sum(sq_fits[:i])
    cumsum_sq_fits = fits # proportional to fits, rather than its square
    cumsum_sq_fits = cumsum_sq_fits / cumsum_sq_fits.sum()
    for i in range(1,len(cumsum_sq_fits)):
        cumsum_sq_fits[i] = cumsum_sq_fits[i-1] + cumsum_sq_fits[i]
    mut_list = [] # list with indexes of individuals to be mutate
    while len(mut_list) < n_mut:
        r = np.random.random()
        candidate = 0
        for i in range(len(fits)):
            if cumsum_sq_fits[i] > r:
                break
            candidate += 1
        if candidate in mut_list:
            continue
        else:
            mut_list.append(candidate)
    print("to mutate: ", end='')
    print(mut_list)
    for idx in mut_list:
        if idx < n_save:
            copy = pop[idx].copy()
            mutate(copy)
            pop[-idx-1] = copy
            pop[-idx-1]['fitness'] = None
            pop[-idx-1]['n_evals'] = 0
        else:
            mutate(pop[idx])
            pop[idx]['fitness'] = None
            pop[idx]['n_evals'] = 0
            
    print('generation %d finished in %s seconds' % (gen, time.time() - start_time))
#     while len(mut_list) < n_mut:
#         min_r = cumsum_sq_fits[n_save] # don't mutate the first n_save individuals
#         r = min_r + (1.-min_r) * np.random.random()
#         candidate = n_save
#         for i in range(n_save, len(fits)):
#             if cumsum_sq_fits[i] > r:
#                 break
#             candidate += 1
#         if candidate in mut_list:
#             continue
#         else:
#             mut_list.append(candidate)
#     print("to mutate: ", end='')
#     print(mut_list)
#     for _ in range(n_mut):
#         idx = np.random.randint(len(pop))
#         mutate(pop[idx])
#         pop[idx]['fitness'] = None
#         pop[idx]['n_evals'] = 0
# Out:
# Generation 0 evaluated. Best fitness: 0.132
# Mean fitness = 0.373
# to replace: [43, 32, 30, 35, 15, 53, 13, 41, 48, 24]
# to mutate: [55, 58, 48, 59, 13, 42]
# generation 0 finished in 3896.679292201996 seconds
# Generation 1 evaluated. Best fitness: 0.146
# Mean fitness = 0.360
# to replace: [19, 27, 44, 5, 42, 54, 53, 36, 30, 45]
# to mutate: [40, 59, 45, 39, 54, 22]
# generation 1 finished in 3867.775689601898 seconds
# Generation 2 evaluated. Best fitness: 0.168
# Mean fitness = 0.335
# to replace: [33, 8, 55, 18, 52, 42, 39, 51, 21, 50]
# to mutate: [28, 43, 24, 21, 42, 2]
# generation 2 finished in 4120.56488609314 seconds
# Generation 3 evaluated. Best fitness: 0.149
# Mean fitness = 0.303
# to replace: [50, 18, 40, 32, 47, 9, 56, 36, 42, 58]
# to mutate: [43, 55, 23, 42, 34, 27]
# generation 3 finished in 4058.8383746147156 seconds
# Generation 4 evaluated. Best fitness: 0.146
# Mean fitness = 0.263
# to replace: [51, 47, 48, 13, 54, 20, 30, 53, 15, 40]
# to mutate: [27, 43, 49, 29, 54, 50]
# generation 4 finished in 4070.7000620365143 seconds
# Generation 5 evaluated. Best fitness: 0.108
# Mean fitness = 0.257
# to replace: [19, 51, 59, 26, 18, 54, 41, 38, 25, 16]
# to mutate: [50, 47, 51, 31, 30, 44]
# generation 5 finished in 4206.911046028137 seconds
# Generation 6 evaluated. Best fitness: 0.099
# Mean fitness = 0.233
# to replace: [42, 54, 51, 24, 9, 56, 58, 39, 41, 16]
# to mutate: [52, 49, 56, 22, 27, 43]
# generation 6 finished in 4399.596182823181 seconds
# Generation 7 evaluated. Best fitness: 0.095
# Mean fitness = 0.212
# to replace: [31, 47, 34, 55, 37, 17, 51, 23, 26, 22]
# to mutate: [31, 56, 34, 42, 35, 37]
# generation 7 finished in 4195.361554145813 seconds
# Generation 8 evaluated. Best fitness: 0.067
# Mean fitness = 0.213
# to replace: [33, 57, 49, 15, 24, 20, 34, 36, 56, 12]
# to mutate: [55, 6, 47, 56, 43, 38]
# generation 8 finished in 4252.258693933487 seconds
# Generation 9 evaluated. Best fitness: 0.080
# Mean fitness = 0.193
# to replace: [57, 29, 35, 20, 39, 52, 27, 14, 6, 11]
# to mutate: [53, 51, 35, 52, 45, 54]
# generation 9 finished in 3477.9268062114716 seconds
# Generation 10 evaluated. Best fitness: 0.078
# Mean fitness = 0.184
# to replace: [4, 50, 33, 25, 24, 46, 12, 28, 42, 55]
# to mutate: [34, 59, 55, 3, 42, 28]
# generation 10 finished in 3727.947970867157 seconds
# Generation 11 evaluated. Best fitness: 0.066
# Mean fitness = 0.174
# to replace: [43, 47, 55, 5, 6, 39, 26, 28, 31, 45]
# to mutate: [46, 48, 41, 29, 35, 57]
# generation 11 finished in 3823.8973677158356 seconds
# Generation 12 evaluated. Best fitness: 0.080
# Mean fitness = 0.185
# to replace: [48, 45, 55, 46, 20, 37, 27, 42, 49, 47]
# to mutate: [30, 50, 47, 21, 13, 44]
# generation 12 finished in 3917.109173297882 seconds
# Generation 13 evaluated. Best fitness: 0.063
# Mean fitness = 0.158
# to replace: [38, 58, 49, 48, 35, 56, 44, 54, 9, 28]
# to mutate: [47, 54, 42, 56, 53, 43]
# generation 13 finished in 4017.537316799164 seconds
# Generation 14 evaluated. Best fitness: 0.084
# Mean fitness = 0.164
# to replace: [19, 25, 53, 35, 32, 52, 16, 20, 14, 51]
# to mutate: [39, 57, 56, 20, 40, 8]
# generation 14 finished in 4004.937469959259 seconds
# Generation 15 evaluated. Best fitness: 0.074
# Mean fitness = 0.156
# to replace: [57, 58, 49, 32, 45, 50, 59, 47, 48, 44]
# to mutate: [57, 24, 54, 58, 49, 31]
# generation 15 finished in 3998.390666246414 seconds
# Generation 16 evaluated. Best fitness: 0.064
# Mean fitness = 0.154
# to replace: [43, 45, 58, 49, 55, 31, 59, 28, 46, 57]
# to mutate: [56, 51, 47, 19, 35, 55]
# generation 16 finished in 3619.5709104537964 seconds
# Generation 17 evaluated. Best fitness: 0.088
# Mean fitness = 0.141
# to replace: [19, 53, 6, 50, 29, 14, 26, 15, 48, 34]
# to mutate: [58, 43, 24, 32, 6, 42]
# generation 17 finished in 3621.615108013153 seconds
# Generation 18 evaluated. Best fitness: 0.085
# Mean fitness = 0.157
# to replace: [37, 30, 59, 16, 7, 58, 15, 9, 33, 52]
# to mutate: [47, 51, 43, 22, 58, 39]
# generation 18 finished in 3748.939869403839 seconds
# Generation 19 evaluated. Best fitness: 0.088
# Mean fitness = 0.137
# to replace: [45, 48, 50, 24, 5, 59, 49, 4, 53, 26]
# to mutate: [52, 43, 57, 56, 33, 42]
# generation 19 finished in 3680.0922927856445 seconds
# Generation 20 evaluated. Best fitness: 0.090
# Mean fitness = 0.148
# to replace: [49, 57, 50, 16, 41, 14, 48, 52, 29, 6]
# to mutate: [55, 17, 15, 52, 58, 30]
# generation 20 finished in 3118.156639099121 seconds
# Generation 21 evaluated. Best fitness: 0.092
# Mean fitness = 0.150
# to replace: [43, 40, 47, 53, 44, 56, 23, 25, 50, 59]
# to mutate: [45, 52, 50, 59, 44, 51]
# generation 21 finished in 3129.3507165908813 seconds
# Generation 22 evaluated. Best fitness: 0.090
# Mean fitness = 0.139
# to replace: [59, 11, 38, 44, 50, 26, 48, 35, 57, 45]
# to mutate: [56, 58, 25, 36, 30, 35]
# generation 22 finished in 3123.34521651268 seconds
# Generation 23 evaluated. Best fitness: 0.081
# Mean fitness = 0.127
# to replace: [56, 29, 45, 59, 46, 55, 43, 49, 58, 48]
# to mutate: [34, 47, 59, 42, 30, 50]
# generation 23 finished in 3020.1832518577576 seconds
# Generation 24 evaluated. Best fitness: 0.071
# Mean fitness = 0.128
# to replace: [44, 16, 55, 52, 51, 31, 59, 40, 50, 58]
# to mutate: [52, 45, 58, 56, 48, 53]
# generation 24 finished in 2896.58145403862 seconds
# Generation 25 evaluated. Best fitness: 0.071
# Mean fitness = 0.129
# to replace: [50, 59, 55, 10, 46, 34, 5, 41, 54, 9]
# to mutate: [22, 45, 53, 54, 29, 37]
# generation 25 finished in 3101.4716272354126 seconds
# Generation 26 evaluated. Best fitness: 0.078
# Mean fitness = 0.133
# to replace: [53, 17, 29, 59, 24, 36, 43, 56, 34, 55]
# to mutate: [36, 50, 19, 33, 57, 42]
# generation 26 finished in 3154.386533975601 seconds
# Generation 27 evaluated. Best fitness: 0.082
# Mean fitness = 0.125
# to replace: [44, 41, 17, 43, 52, 49, 38, 7, 14, 13]
# to mutate: [57, 49, 40, 15, 46, 22]
# generation 27 finished in 2995.5249722003937 seconds
# Generation 28 evaluated. Best fitness: 0.076
# Mean fitness = 0.131
# to replace: [57, 45, 35, 37, 32, 28, 39, 42, 50, 29]
# to mutate: [34, 57, 14, 30, 44, 43]
# generation 28 finished in 3192.9694080352783 seconds
# Generation 29 evaluated. Best fitness: 0.073
# Mean fitness = 0.132
# to replace: [33, 26, 11, 53, 43, 54, 51, 16, 40, 59]
# to mutate: [59, 54, 10, 47, 13, 14]
# generation 29 finished in 3159.768898963928 seconds
# Generation 30 evaluated. Best fitness: 0.072
# Mean fitness = 0.131
# to replace: [6, 34, 57, 39, 49, 51, 18, 29, 40, 7]
# to mutate: [54, 38, 51, 37, 58, 8]
# generation 30 finished in 3140.406408071518 seconds
# Generation 31 evaluated. Best fitness: 0.073
# Mean fitness = 0.138
# to replace: [54, 14, 59, 8, 28, 38, 45, 12, 33, 30]
# to mutate: [56, 38, 47, 55, 19, 49]
# generation 31 finished in 3224.091645002365 seconds
# Generation 32 evaluated. Best fitness: 0.073
# Mean fitness = 0.133
# to replace: [58, 18, 54, 48, 53, 8, 6, 15, 47, 10]
# to mutate: [58, 42, 52, 26, 30, 23]
# generation 32 finished in 3246.2057843208313 seconds
# Generation 33 evaluated. Best fitness: 0.073
# Mean fitness = 0.136
# to replace: [45, 4, 36, 41, 7, 24, 25, 21, 33, 32]
# to mutate: [46, 11, 51, 40, 35, 38]
# generation 33 finished in 3160.6169016361237 seconds
# Generation 34 evaluated. Best fitness: 0.073
# Mean fitness = 0.126
# to replace: [44, 26, 46, 57, 11, 35, 21, 45, 52, 28]
# to mutate: [39, 24, 45, 48, 57, 54]
# generation 34 finished in 3150.610134601593 seconds
# Generation 35 evaluated. Best fitness: 0.057
# Mean fitness = 0.130
# to replace: [9, 40, 59, 29, 56, 33, 51, 14, 46, 12]
# to mutate: [11, 45, 52, 53, 47, 20]
# generation 35 finished in 2991.9353613853455 seconds
# Generation 36 evaluated. Best fitness: 0.062
# Mean fitness = 0.123
# to replace: [49, 47, 44, 46, 31, 59, 51, 50, 55, 40]
# to mutate: [59, 42, 50, 43, 58, 54]
# generation 36 finished in 2769.867760181427 seconds
# Generation 37 evaluated. Best fitness: 0.073
# Mean fitness = 0.125
# to replace: [19, 57, 6, 37, 58, 50, 59, 49, 32, 43]
# to mutate: [51, 39, 37, 55, 33, 35]
# generation 37 finished in 1970.2853214740753 seconds
# Generation 38 evaluated. Best fitness: 0.073
# Mean fitness = 0.102
# to replace: [38, 22, 50, 18, 35, 47, 56, 46, 16, 13]
# to mutate: [43, 36, 49, 13, 14, 59]
# generation 38 finished in 1865.2351369857788 seconds
# Generation 39 evaluated. Best fitness: 0.064
# Mean fitness = 0.109
# to replace: [23, 11, 41, 53, 32, 35, 19, 42, 54, 5]
# to mutate: [53, 43, 39, 11, 48, 52]
# generation 39 finished in 1831.9661481380463 seconds
# Generation 40 evaluated. Best fitness: 0.057
# Mean fitness = 0.113
# to replace: [32, 59, 43, 30, 46, 44, 5, 21, 7, 37]
# to mutate: [36, 54, 57, 33, 51, 28]
# generation 40 finished in 1968.7804207801819 seconds
# Generation 41 evaluated. Best fitness: 0.052
# Mean fitness = 0.129
# to replace: [27, 19, 16, 7, 55, 41, 29, 46, 11, 24]
# to mutate: [20, 52, 34, 13, 57, 54]
# generation 41 finished in 2386.7661294937134 seconds
# Generation 42 evaluated. Best fitness: 0.065
# Mean fitness = 0.125
# to replace: [51, 15, 54, 27, 24, 58, 23, 39, 42, 55]
# to mutate: [31, 56, 25, 52, 53, 43]
# generation 42 finished in 2901.0841035842896 seconds
# Generation 43 evaluated. Best fitness: 0.064
# Mean fitness = 0.132
# to replace: [14, 58, 50, 59, 37, 57, 10, 35, 13, 32]
# to mutate: [49, 21, 50, 41, 30, 55]
# generation 43 finished in 2830.2327797412872 seconds
# Generation 44 evaluated. Best fitness: 0.064
# Mean fitness = 0.120
# to replace: [51, 46, 12, 58, 23, 14, 28, 41, 56, 18]
# to mutate: [44, 26, 53, 52, 59, 42]
# generation 44 finished in 2432.048189640045 seconds
# Generation 45 evaluated. Best fitness: 0.060
# Mean fitness = 0.119
# to replace: [38, 57, 31, 24, 26, 58, 46, 39, 34, 59]
# to mutate: [48, 46, 52, 56, 20, 45]
# generation 45 finished in 2719.2525186538696 seconds
# Generation 46 evaluated. Best fitness: 0.064
# Mean fitness = 0.123
# to replace: [53, 57, 51, 39, 12, 42, 13, 52, 28, 50]
# to mutate: [23, 58, 21, 32, 53, 11]
# generation 46 finished in 2055.065991163254 seconds
# Generation 47 evaluated. Best fitness: 0.064
# Mean fitness = 0.115
# to replace: [42, 33, 14, 56, 59, 21, 37, 49, 58, 36]
# to mutate: [53, 25, 29, 23, 41, 57]
# generation 47 finished in 1942.6733100414276 seconds
# Generation 48 evaluated. Best fitness: 0.060
# Mean fitness = 0.109
# to replace: [27, 57, 13, 17, 53, 42, 36, 59, 11, 6]
# to mutate: [59, 47, 58, 48, 17, 43]
# generation 48 finished in 1858.655106306076 seconds
# Generation 49 evaluated. Best fitness: 0.064
# Mean fitness = 0.125
# to replace: [13, 59, 58, 25, 4, 44, 48, 52, 17, 38]
# to mutate: [47, 27, 58, 53, 41, 54]
# generation 49 finished in 1823.7063717842102 seconds
# Generation 50 evaluated. Best fitness: 0.056
# Mean fitness = 0.121
# to replace: [51, 31, 40, 38, 55, 4, 43, 49, 34, 16]
# to mutate: [51, 29, 35, 48, 19, 30]
# generation 50 finished in 1913.8071975708008 seconds
# Generation 51 evaluated. Best fitness: 0.063
# Mean fitness = 0.119
# to replace: [59, 42, 55, 6, 13, 19, 32, 44, 39, 53]
# to mutate: [11, 46, 12, 53, 22, 25]
# generation 51 finished in 1839.1003513336182 seconds
# Generation 52 evaluated. Best fitness: 0.064
# Mean fitness = 0.115
# to replace: [58, 31, 44, 48, 56, 59, 11, 35, 53, 54]
# to mutate: [57, 37, 11, 24, 17, 51]
# generation 52 finished in 2332.4204325675964 seconds
# Generation 53 evaluated. Best fitness: 0.064
# Mean fitness = 0.108
# to replace: [18, 46, 23, 11, 49, 50, 59, 35, 44, 31]
# to mutate: [53, 15, 49, 56, 52, 51]
# generation 53 finished in 1974.2472968101501 seconds
# Generation 54 evaluated. Best fitness: 0.064
# Mean fitness = 0.113
# to replace: [52, 36, 32, 59, 57, 22, 55, 11, 47, 37]
# to mutate: [29, 34, 47, 16, 51, 49]
# generation 54 finished in 1886.930526971817 seconds
# Generation 55 evaluated. Best fitness: 0.064
# Mean fitness = 0.107
# to replace: [55, 59, 22, 19, 18, 35, 56, 23, 33, 46]
# to mutate: [48, 59, 39, 55, 36, 37]
# generation 55 finished in 1838.4945328235626 seconds
# Generation 56 evaluated. Best fitness: 0.064
# Mean fitness = 0.120
# to replace: [54, 15, 57, 38, 26, 37, 58, 46, 50, 25]
# to mutate: [43, 49, 50, 55, 46, 56]
# generation 56 finished in 1877.5747532844543 seconds
# Generation 57 evaluated. Best fitness: 0.060
# Mean fitness = 0.102
# to replace: [57, 18, 22, 45, 7, 46, 28, 13, 43, 59]
# to mutate: [5, 16, 56, 59, 51, 34]
# generation 57 finished in 1779.8520710468292 seconds
# Generation 58 evaluated. Best fitness: 0.064
# Mean fitness = 0.104
# to replace: [52, 7, 8, 53, 30, 46, 19, 13, 55, 34]
# to mutate: [56, 39, 54, 32, 17, 58]
# generation 58 finished in 1987.0364117622375 seconds
# Generation 59 evaluated. Best fitness: 0.064
# Mean fitness = 0.112
# to replace: [23, 26, 49, 59, 9, 52, 20, 46, 15, 16]
# to mutate: [34, 32, 53, 36, 33, 55]
# generation 59 finished in 1903.0031468868256 seconds
# Generation 60 evaluated. Best fitness: 0.064
# Mean fitness = 0.116
# to replace: [52, 56, 50, 40, 26, 48, 38, 59, 28, 15]
# to mutate: [24, 56, 41, 50, 46, 59]
# generation 60 finished in 1860.2985560894012 seconds
# Generation 61 evaluated. Best fitness: 0.064
# Mean fitness = 0.108
# to replace: [53, 16, 34, 43, 56, 30, 57, 41, 48, 7]
# to mutate: [45, 41, 44, 58, 48, 46]
# generation 61 finished in 1921.748197555542 seconds
# Generation 62 evaluated. Best fitness: 0.040
# Mean fitness = 0.102
# to replace: [40, 45, 56, 52, 54, 5, 20, 53, 57, 58]
# to mutate: [47, 56, 28, 37, 21, 38]
# generation 62 finished in 1748.0030903816223 seconds
# Generation 63 evaluated. Best fitness: 0.064
# Mean fitness = 0.114
# to replace: [37, 29, 32, 4, 24, 44, 57, 52, 58, 50]
# to mutate: [17, 32, 55, 59, 39, 49]
# generation 63 finished in 1691.133497953415 seconds
# Generation 64 evaluated. Best fitness: 0.058
# Mean fitness = 0.107
# to replace: [48, 32, 21, 57, 54, 59, 45, 14, 41, 4]
# to mutate: [38, 54, 12, 59, 55, 34]
# generation 64 finished in 1683.9743149280548 seconds
# Generation 65 evaluated. Best fitness: 0.054
# Mean fitness = 0.103
# to replace: [38, 10, 13, 29, 31, 43, 48, 41, 39, 54]
# to mutate: [16, 18, 58, 42, 41, 38]
# generation 65 finished in 1891.8601920604706 seconds
# Generation 66 evaluated. Best fitness: 0.055
# Mean fitness = 0.100
# to replace: [53, 48, 54, 59, 58, 43, 21, 57, 49, 34]
# to mutate: [17, 28, 50, 37, 49, 58]
# generation 66 finished in 1950.3506789207458 seconds
# Generation 67 evaluated. Best fitness: 0.058
# Mean fitness = 0.111
# to replace: [59, 47, 52, 8, 22, 42, 45, 17, 38, 25]
# to mutate: [40, 56, 41, 31, 55, 26]
# generation 67 finished in 1893.242615699768 seconds
# Generation 68 evaluated. Best fitness: 0.058
# Mean fitness = 0.110
# to replace: [52, 43, 59, 47, 40, 11, 48, 20, 12, 45]
# to mutate: [53, 58, 33, 36, 44, 37]
# generation 68 finished in 1971.5336136817932 seconds
# Generation 69 evaluated. Best fitness: 0.058
# Mean fitness = 0.114
# to replace: [51, 33, 55, 15, 50, 41, 40, 29, 44, 57]
# to mutate: [49, 59, 31, 48, 51, 38]
# generation 69 finished in 1913.853851556778 seconds
# Generation 70 evaluated. Best fitness: 0.041
# Mean fitness = 0.109
# to replace: [59, 9, 50, 39, 57, 16, 41, 17, 51, 13]
# to mutate: [36, 53, 45, 24, 38, 21]
# generation 70 finished in 1797.2894797325134 seconds
# Generation 71 evaluated. Best fitness: 0.058
# Mean fitness = 0.107
# to replace: [44, 26, 42, 5, 29, 50, 27, 24, 33, 37]
# to mutate: [43, 57, 54, 19, 56, 47]
# generation 71 finished in 1845.496325492859 seconds
# Generation 72 evaluated. Best fitness: 0.058
# Mean fitness = 0.107
# to replace: [50, 49, 58, 56, 11, 15, 25, 51, 4, 8]
# to mutate: [43, 41, 54, 37, 38, 30]
# generation 72 finished in 1938.2631998062134 seconds
# Generation 73 evaluated. Best fitness: 0.058
# Mean fitness = 0.112
# to replace: [48, 57, 49, 59, 47, 46, 45, 54, 58, 50]
# to mutate: [16, 54, 40, 55, 52, 53]
# generation 73 finished in 1832.3071405887604 seconds
# Generation 74 evaluated. Best fitness: 0.058
# Mean fitness = 0.091
# to replace: [59, 55, 43, 11, 49, 52, 28, 39, 42, 45]
# to mutate: [52, 57, 47, 41, 44, 59]
# generation 74 finished in 1624.9150650501251 seconds
# Generation 75 evaluated. Best fitness: 0.058
# Mean fitness = 0.090
# to replace: [56, 31, 50, 19, 59, 57, 9, 38, 8, 7]
# to mutate: [58, 37, 32, 54, 36, 42]
# generation 75 finished in 1581.5205297470093 seconds
# Generation 76 evaluated. Best fitness: 0.058
# Mean fitness = 0.093
# to replace: [19, 34, 55, 44, 40, 41, 29, 35, 53, 58]
# to mutate: [46, 57, 43, 28, 27, 29]
# generation 76 finished in 1673.512672662735 seconds
# Generation 77 evaluated. Best fitness: 0.058
# Mean fitness = 0.091
# to replace: [56, 44, 30, 59, 52, 16, 57, 35, 39, 42]
# to mutate: [34, 52, 57, 20, 35, 47]
# generation 77 finished in 1658.6114525794983 seconds
# Generation 78 evaluated. Best fitness: 0.058
# Mean fitness = 0.099
# to replace: [40, 54, 37, 59, 51, 34, 30, 15, 43, 38]
# to mutate: [53, 52, 49, 14, 44, 55]
# generation 78 finished in 1719.2887032032013 seconds
# Generation 79 evaluated. Best fitness: 0.058
# Mean fitness = 0.096
# to replace: [49, 30, 59, 17, 50, 10, 45, 40, 58, 25]
# to mutate: [46, 26, 8, 32, 47, 44]
# generation 79 finished in 1640.2733755111694 seconds
# Generation 80 evaluated. Best fitness: 0.058
# Mean fitness = 0.098
# to replace: [58, 24, 46, 50, 56, 59, 55, 43, 42, 32]
# to mutate: [24, 16, 32, 35, 41, 52]
# generation 80 finished in 1722.4070887565613 seconds
# Generation 81 evaluated. Best fitness: 0.058
# Mean fitness = 0.101
# to replace: [50, 8, 4, 59, 6, 52, 11, 58, 43, 45]
# to mutate: [34, 53, 30, 41, 38, 49]
# generation 81 finished in 1658.032790184021 seconds
# Generation 82 evaluated. Best fitness: 0.058
# Mean fitness = 0.105
# to replace: [33, 40, 52, 59, 54, 56, 50, 4, 55, 13]
# to mutate: [6, 59, 55, 21, 37, 39]
# generation 82 finished in 1682.9222974777222 seconds
# Generation 83 evaluated. Best fitness: 0.058
# Mean fitness = 0.102
# to replace: [38, 22, 58, 43, 49, 30, 55, 31, 42, 46]
# to mutate: [45, 24, 54, 51, 47, 56]
# generation 83 finished in 1669.1575953960419 seconds
# Generation 84 evaluated. Best fitness: 0.058
# Mean fitness = 0.096
# to replace: [52, 18, 33, 31, 58, 39, 57, 51, 6, 59]
# to mutate: [53, 38, 59, 34, 50, 42]
# generation 84 finished in 1632.3923976421356 seconds
# Generation 85 evaluated. Best fitness: 0.058
# Mean fitness = 0.092
# to replace: [44, 51, 39, 46, 43, 47, 57, 53, 58, 59]
# to mutate: [56, 57, 42, 43, 23, 37]
# generation 85 finished in 1625.4616153240204 seconds
# Generation 86 evaluated. Best fitness: 0.058
# Mean fitness = 0.095
# to replace: [44, 53, 23, 57, 59, 48, 58, 52, 56, 22]
# to mutate: [42, 44, 55, 49, 5, 47]
# generation 86 finished in 1661.966490983963 seconds
# Generation 87 evaluated. Best fitness: 0.058
# Mean fitness = 0.091
# to replace: [21, 59, 53, 15, 30, 49, 18, 16, 58, 57]
# to mutate: [58, 52, 18, 44, 29, 43]
# generation 87 finished in 1628.5263671875 seconds
# Generation 88 evaluated. Best fitness: 0.056
# Mean fitness = 0.094
# to replace: [6, 53, 14, 20, 41, 24, 55, 54, 50, 49]
# to mutate: [58, 42, 56, 50, 52, 53]
# generation 88 finished in 1639.9453139305115 seconds
# Generation 89 evaluated. Best fitness: 0.058
# Mean fitness = 0.094
# to replace: [22, 55, 4, 34, 54, 57, 40, 59, 12, 58]
# to mutate: [32, 14, 53, 47, 56, 52]
# generation 89 finished in 1674.572299003601 seconds
# Generation 90 evaluated. Best fitness: 0.058
# Mean fitness = 0.092
# to replace: [57, 39, 53, 56, 31, 14, 45, 52, 40, 54]
# to mutate: [5, 45, 41, 44, 51, 52]
# generation 90 finished in 1632.939521074295 seconds
# Generation 91 evaluated. Best fitness: 0.044
# Mean fitness = 0.103
# to replace: [56, 59, 41, 47, 58, 12, 10, 36, 48, 50]
# to mutate: [59, 42, 45, 29, 56, 5]
# generation 91 finished in 1608.4755005836487 seconds
# Generation 92 evaluated. Best fitness: 0.058
# Mean fitness = 0.092
# to replace: [48, 58, 43, 52, 44, 46, 55, 39, 56, 50]
# to mutate: [28, 49, 55, 14, 53, 33]
# generation 92 finished in 1670.408614397049 seconds
# Generation 93 evaluated. Best fitness: 0.058
# Mean fitness = 0.101
# to replace: [47, 8, 48, 57, 51, 53, 44, 59, 52, 30]
# to mutate: [24, 49, 25, 56, 45, 57]
# generation 93 finished in 1599.635580778122 seconds
# Generation 94 evaluated. Best fitness: 0.058
# Mean fitness = 0.093
# to replace: [20, 50, 47, 51, 16, 31, 43, 42, 53, 54]
# to mutate: [57, 13, 36, 45, 48, 52]
# generation 94 finished in 1595.0586133003235 seconds
# Generation 95 evaluated. Best fitness: 0.058
# Mean fitness = 0.082
# to replace: [18, 56, 19, 38, 58, 52, 53, 30, 54, 17]
# to mutate: [55, 26, 46, 48, 53, 40]
# generation 95 finished in 1598.1210799217224 seconds
# Generation 96 evaluated. Best fitness: 0.058
# Mean fitness = 0.096
# to replace: [50, 59, 52, 5, 58, 56, 22, 43, 49, 8]
# to mutate: [10, 50, 43, 52, 35, 33]
# generation 96 finished in 1610.3588757514954 seconds
# Generation 97 evaluated. Best fitness: 0.058
# Mean fitness = 0.092
# to replace: [8, 43, 21, 47, 58, 59, 51, 49, 45, 9]
# to mutate: [46, 52, 51, 49, 50, 33]
# generation 97 finished in 1639.9324929714203 seconds
# Generation 98 evaluated. Best fitness: 0.058
# Mean fitness = 0.102
# to replace: [52, 56, 51, 24, 54, 29, 40, 18, 4, 57]
# to mutate: [21, 46, 55, 37, 44, 29]
# generation 98 finished in 1629.460997581482 seconds
# Generation 99 evaluated. Best fitness: 0.058
# Mean fitness = 0.109
# to replace: [11, 27, 42, 59, 56, 41, 26, 55, 33, 7]
# to mutate: [57, 29, 55, 56, 59, 58]
# generation 99 finished in 1663.5982868671417 seconds

# %%
# print final population
for dic in pop[:5]:
    print('{',end='')
    for name in dic.keys():
        if name != 'fitness' or dic['fitness'] != None:
            print("\'%s\':%.2f, " % (name, dic[name]), end='')
    print('}\n')

pop[0]

# %%
# Save the final population
fname = "v3_nst_afx_pop"
fname += "_" + datetime.now().strftime('%Y-%m-%d__%H_%M')
with open(fname, 'wb') as f:
    pickle.dump(pop, f)
    f.close()

# %%
# Load a saved population
import pickle
fname = 'v3_nst_afx_pop'
with (open(fname, "rb")) as f:
    results = pickle.load(f)
    f.close()

# %%
# Test a configuation
cfg_id = 0 # index in the population for the configuration
net, pops_dict, hand_coords, m_idxs, t_pres, _  = net_from_cfg(pop[cfg_id])
pops_names = ['SF', 'SP', 'SPF', 'AL', 'AF', 'SP_CHG', 'CE', 'CI', 'M', 'ACT', 'P']
for name in pops_names:
    exec("%s = %s"% (name, str(pops_dict[name])))

start_time = time.time()
times, data, plant_data  = net.flat_run(600.)
#times, data, plant_data  = net.run(40.)
print('Execution time is %s seconds' % (time.time() - start_time))
data = np.array(data)
#Execution time is 8.687349319458008 seconds  << before sc_inp_sum_mp, flat_run(5.)

# %% [raw]
# # reducing the scope of the plots
# data_back = data
# times_back = times
# plant_data_back = [np.array([])]
# plant_data_back[0] = plant_data[0]
#
# first_idx=100*200
# second_idx=115*200
# times = times[first_idx:second_idx]
# data = data[:, first_idx:second_idx]
# plant_data[0] = plant_data[0][first_idx:second_idx,:]

# %% [raw]
# # recover the data
# data = data_back
# plant_data[0] = plant_data_back[0]
# times = times_back

# %% [markdown]
# Same history as `v3_nst_afx`
# ...
